# %%
import pandas as pd
import numpy as np
import random
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
data = 'Online Retail.xlsx'
df = pd.read_excel(data)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df['Country'].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
basket = (df[df['Country'] =="United Kingdom"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
basket.head()
# Out:
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                         0.0                      0.0
# 536366                         0.0                      0.0
# 536367                         0.0                      0.0
# 536368                         0.0                      0.0
# 536369                         0.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                          0.0                         0.0
# 536366                          0.0                         0.0
# 536367                          0.0                         0.0
# 536368                          0.0                         0.0
# 536369                          0.0                         0.0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536365                             0.0                        0.0
# 536366                             0.0                        0.0
# 536367                             0.0                        0.0
# 536368                             0.0                        0.0
# 536369                             0.0                        0.0
#
# Description  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536365                                0.0                               0.0
# 536366                                0.0                               0.0
# 536367                                0.0                               0.0
# 536368                                0.0                               0.0
# 536369                                0.0                               0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                   0.0                            0.0
# 536366                                   0.0                            0.0
# 536367                                   0.0                            0.0
# 536368                                   0.0                            0.0
# 536369                                   0.0                            0.0
#
# Description        ...          wrongly coded 20713  wrongly coded 23343  \
# InvoiceNo          ...
# 536365             ...                          0.0                  0.0
# 536366             ...                          0.0                  0.0
# 536367             ...                          0.0                  0.0
# 536368             ...                          0.0                  0.0
# 536369             ...                          0.0                  0.0
#
# Description  wrongly coded-23343  wrongly marked  wrongly marked 23343  \
# InvoiceNo
# 536365                       0.0             0.0                   0.0
# 536366                       0.0             0.0                   0.0
# 536367                       0.0             0.0                   0.0
# 536368                       0.0             0.0                   0.0
# 536369                       0.0             0.0                   0.0
#
# Description  wrongly marked carton 22804  wrongly marked. 23343 in box  \
# InvoiceNo
# 536365                               0.0                           0.0
# 536366                               0.0                           0.0
# 536367                               0.0                           0.0
# 536368                               0.0                           0.0
# 536369                               0.0                           0.0
#
# Description  wrongly sold (22719) barcode  wrongly sold as sets  \
# InvoiceNo
# 536365                                0.0                   0.0
# 536366                                0.0                   0.0
# 536367                                0.0                   0.0
# 536368                                0.0                   0.0
# 536369                                0.0                   0.0
#
# Description  wrongly sold sets
# InvoiceNo
# 536365                     0.0
# 536366                     0.0
# 536367                     0.0
# 536368                     0.0
# 536369                     0.0
#
# [5 rows x 4175 columns]

# %%
basket.shape
# Out:
# (18667, 4175)

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
basket_sets.shape
# Out:
# (18667, 4174)

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.01, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)
rules.head()
# Out:
#                                          antecedants  \
# 0  (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG SCA...
# 1  (JUMBO BAG OWLS, JUMBO SHOPPER VINTAGE RED PAI...
# 2          (JUMBO BAG OWLS, JUMBO BAG RED RETROSPOT)
# 3                  (JUMBO BAG CHARLIE AND LOLA TOYS)
# 4  (LUNCH BAG RED RETROSPOT, RED RETROSPOT CHARLO...
#
#                            consequents  antecedent support  \
# 0            (JUMBO BAG RED RETROSPOT)            0.013178
# 1            (JUMBO BAG RED RETROSPOT)            0.013500
# 2  (JUMBO SHOPPER VINTAGE RED PAISLEY)            0.019821
# 3            (JUMBO BAG RED RETROSPOT)            0.015803
# 4           (STRAWBERRY CHARLOTTE BAG)            0.019339
#
#    consequent support   support  confidence       lift  leverage  conviction
# 0            0.103820  0.010982    0.833333   8.026746  0.009614    5.377083
# 1            0.103820  0.010125    0.750000   7.224071  0.008723    3.584722
# 2            0.060695  0.010125    0.510811   8.415980  0.008922    1.920126
# 3            0.103820  0.010286    0.650847   6.269025  0.008645    2.566730
# 4            0.036053  0.011839    0.612188  16.980268  0.011142    2.485606

# %%
rules["antecedant_len"] = rules["antecedants"].apply(lambda x: len(x))
rules["consequentst_len"] = rules["consequents"].apply(lambda x: len(x))
rules.head()
# Out:
#                                          antecedants  \
# 0  (JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG SCA...
# 1  (JUMBO BAG OWLS, JUMBO SHOPPER VINTAGE RED PAI...
# 2          (JUMBO BAG OWLS, JUMBO BAG RED RETROSPOT)
# 3                  (JUMBO BAG CHARLIE AND LOLA TOYS)
# 4  (LUNCH BAG RED RETROSPOT, RED RETROSPOT CHARLO...
#
#                            consequents  antecedent support  \
# 0            (JUMBO BAG RED RETROSPOT)            0.013178
# 1            (JUMBO BAG RED RETROSPOT)            0.013500
# 2  (JUMBO SHOPPER VINTAGE RED PAISLEY)            0.019821
# 3            (JUMBO BAG RED RETROSPOT)            0.015803
# 4           (STRAWBERRY CHARLOTTE BAG)            0.019339
#
#    consequent support   support  confidence       lift  leverage  conviction  \
# 0            0.103820  0.010982    0.833333   8.026746  0.009614    5.377083
# 1            0.103820  0.010125    0.750000   7.224071  0.008723    3.584722
# 2            0.060695  0.010125    0.510811   8.415980  0.008922    1.920126
# 3            0.103820  0.010286    0.650847   6.269025  0.008645    2.566730
# 4            0.036053  0.011839    0.612188  16.980268  0.011142    2.485606
#
#    antecedant_len  consequentst_len
# 0               2                 1
# 1               2                 1
# 2               2                 1
# 3               1                 1
# 4               2                 1

# %%
rules['antecedant_len'].value_counts()
# Out:
# 2    641
# 1    300
# 3    109
# 4      5
# Name: antecedant_len, dtype: int64

# %%
rules['consequentst_len'].value_counts()
# Out:
# 1    948
# 2    102
# 3      5
# Name: consequentst_len, dtype: int64

# %%
rules.shape
# Out:
# (1055, 11)

# %%
antec = rules['antecedants'].values.tolist()

# %%
conse = rules['consequents'].values.tolist()

# %%
def process(antec,conse):
    all_a = []
    all_c = []
    for a,c in zip(antec,conse):
        str_a = ', '.join(list(a))
        str_c = ', '.join(list(c))
        all_a.append(str_a)
        all_c.append(str_c)
        
    return all_a,all_c

# %%
ar_antec, ar_conse = process(antec,conse)

# %%
labels = np.ones(rules.shape[0], dtype=int)

# %%
col = ["Association Rule antecedants", 
       "Association Rule consequents", "label"]

# %%
all_items_df = pd.DataFrame({"Association Rule antecedants":ar_antec,
                             "Association Rule consequents":ar_conse,
                             "label":labels
                            }, columns = col)

# %%
all_items_df.head(10)
# Out:
#                            Association Rule antecedants  \
# 0     JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG SCAN...
# 1     JUMBO BAG OWLS, JUMBO SHOPPER VINTAGE RED PAISLEY
# 2               JUMBO BAG OWLS, JUMBO BAG RED RETROSPOT
# 3                       JUMBO BAG CHARLIE AND LOLA TOYS
# 4     LUNCH BAG RED RETROSPOT, RED RETROSPOT CHARLOT...
# 5     LUNCH BAG RED RETROSPOT, STRAWBERRY CHARLOTTE BAG
# 6                                      HERB MARKER MINT
# 7                                     HERB MARKER BASIL
# 8     WOODEN PICTURE FRAME WHITE FINISH, WHITE HANGI...
# 9     WOODEN FRAME ANTIQUE WHITE, WHITE HANGING HEAR...
# 10    JUMBO STORAGE BAG SUKI, JUMBO BAG WOODLAND ANI...
# 11    JUMBO STORAGE BAG SUKI, DOTCOM POSTAGE, JUMBO ...
# 12    DOTCOM POSTAGE, JUMBO BAG WOODLAND ANIMALS, JU...
# 13    JUMBO STORAGE BAG SUKI, JUMBO BAG WOODLAND ANI...
# 14               JUMBO STORAGE BAG SUKI, DOTCOM POSTAGE
# 15           JUMBO BAG WOODLAND ANIMALS, DOTCOM POSTAGE
# 16              LUNCH BAG CARS BLUE, LUNCH BAG WOODLAND
# 17          LUNCH BAG WOODLAND, LUNCH BAG  BLACK SKULL.
# 18          JUMBO BAG PINK POLKADOT, JUMBO BAG ALPHABET
# 19          JUMBO BAG ALPHABET, JUMBO BAG RED RETROSPOT
# 20    LUNCH BAG SPACEBOY DESIGN, LUNCH BAG APPLE DESIGN
# 21          LUNCH BAG CARS BLUE, LUNCH BAG APPLE DESIGN
# 22                 JUMBO BAG ALPHABET, JUMBO BAG APPLES
# 23          JUMBO BAG ALPHABET, JUMBO BAG RED RETROSPOT
# 24                             STRAWBERRY CHARLOTTE BAG
# 25                                       JUMBO BAG TOYS
# 26    CHARLOTTE BAG SUKI DESIGN, RED RETROSPOT CHARL...
# 27    CHARLOTTE BAG SUKI DESIGN, CHARLOTTE BAG PINK ...
# 28    RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG PIN...
# 29                              LUNCH BAG PINK POLKADOT
# ...                                                 ...
# 1025  JUMBO BAG PINK VINTAGE PAISLEY, JUMBO BAG RED ...
# 1026  JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG P...
# 1027   JUMBO STORAGE BAG SKULLS, JUMBO STORAGE BAG SUKI
# 1028  JUMBO STORAGE BAG SKULLS, JUMBO BAG WOODLAND A...
# 1029   JUMBO STORAGE BAG SKULLS, JUMBO STORAGE BAG SUKI
# 1030  JUMBO STORAGE BAG SKULLS, JUMBO BAG RED RETROSPOT
# 1031  CHARLOTTE BAG SUKI DESIGN, RED RETROSPOT CHARL...
# 1032  CHARLOTTE BAG SUKI DESIGN, RED RETROSPOT CHARL...
# 1033  CHARLOTTE BAG SUKI DESIGN, WOODLAND CHARLOTTE ...
# 1034  RED RETROSPOT CHARLOTTE BAG, WOODLAND CHARLOTT...
# 1035  CHARLOTTE BAG SUKI DESIGN, RED RETROSPOT CHARL...
# 1036  CHARLOTTE BAG SUKI DESIGN, CHARLOTTE BAG PINK ...
# 1037  CHARLOTTE BAG SUKI DESIGN, WOODLAND CHARLOTTE BAG
# 1038  RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG PIN...
# 1039  RED RETROSPOT CHARLOTTE BAG, WOODLAND CHARLOTT...
# 1040  WOODLAND CHARLOTTE BAG, CHARLOTTE BAG PINK POL...
# 1041                   SINGLE HEART ZINC T-LIGHT HOLDER
# 1042                     CHARLOTTE BAG VINTAGE ALPHABET
# 1043  JUMBO  BAG BAROQUE BLACK WHITE, JUMBO BAG WOOD...
# 1044  PACK OF 72 RETROSPOT CAKE CASES, RED RETROSPOT...
# 1045  PACK OF 72 RETROSPOT CAKE CASES, WOODLAND CHAR...
# 1046    LUNCH BAG RED RETROSPOT, LUNCH BAG APPLE DESIGN
# 1047    LUNCH BAG APPLE DESIGN, LUNCH BAG PINK POLKADOT
# 1048  GREEN REGENCY TEACUP AND SAUCER, WHITE HANGING...
# 1049  ROSES REGENCY TEACUP AND SAUCER, WHITE HANGING...
# 1050                          ALARM CLOCK BAKELIKE PINK
# 1051                            JUMBO BAG VINTAGE DOILY
# 1052         JUMBO BAG TOYS, JUMBO BAG WOODLAND ANIMALS
# 1053                     JUMBO BAG TOYS, DOTCOM POSTAGE
# 1054         JUMBO BAG WOODLAND ANIMALS, DOTCOM POSTAGE
#
#                            Association Rule consequents  label
# 0                               JUMBO BAG RED RETROSPOT      1
# 1                               JUMBO BAG RED RETROSPOT      1
# 2                     JUMBO SHOPPER VINTAGE RED PAISLEY      1
# 3                               JUMBO BAG RED RETROSPOT      1
# 4                              STRAWBERRY CHARLOTTE BAG      1
# 5                           RED RETROSPOT CHARLOTTE BAG      1
# 6                                     HERB MARKER BASIL      1
# 7                                      HERB MARKER MINT      1
# 8                            WOODEN FRAME ANTIQUE WHITE      1
# 9                     WOODEN PICTURE FRAME WHITE FINISH      1
# 10                                       DOTCOM POSTAGE      1
# 11                           JUMBO BAG WOODLAND ANIMALS      1
# 12                               JUMBO STORAGE BAG SUKI      1
# 13                              JUMBO BAG RED RETROSPOT      1
# 14    JUMBO BAG WOODLAND ANIMALS, JUMBO BAG RED RETR...      1
# 15      JUMBO STORAGE BAG SUKI, JUMBO BAG RED RETROSPOT      1
# 16                              LUNCH BAG  BLACK SKULL.      1
# 17                                  LUNCH BAG CARS BLUE      1
# 18                              JUMBO BAG RED RETROSPOT      1
# 19                              JUMBO BAG PINK POLKADOT      1
# 20                                  LUNCH BAG CARS BLUE      1
# 21                            LUNCH BAG SPACEBOY DESIGN      1
# 22                              JUMBO BAG RED RETROSPOT      1
# 23                                     JUMBO BAG APPLES      1
# 24                            CHARLOTTE BAG SUKI DESIGN      1
# 25                              JUMBO BAG RED RETROSPOT      1
# 26                          CHARLOTTE BAG PINK POLKADOT      1
# 27                          RED RETROSPOT CHARLOTTE BAG      1
# 28                            CHARLOTTE BAG SUKI DESIGN      1
# 29                              LUNCH BAG RED RETROSPOT      1
# ...                                                 ...    ...
# 1025                  JUMBO SHOPPER VINTAGE RED PAISLEY      1
# 1026                            JUMBO BAG RED RETROSPOT      1
# 1027                         JUMBO BAG WOODLAND ANIMALS      1
# 1028                             JUMBO STORAGE BAG SUKI      1
# 1029                            JUMBO BAG RED RETROSPOT      1
# 1030                             JUMBO STORAGE BAG SUKI      1
# 1031                             WOODLAND CHARLOTTE BAG      1
# 1032                        CHARLOTTE BAG PINK POLKADOT      1
# 1033                        RED RETROSPOT CHARLOTTE BAG      1
# 1034                          CHARLOTTE BAG SUKI DESIGN      1
# 1035  WOODLAND CHARLOTTE BAG, CHARLOTTE BAG PINK POL...      1
# 1036  RED RETROSPOT CHARLOTTE BAG, WOODLAND CHARLOTT...      1
# 1037  RED RETROSPOT CHARLOTTE BAG, CHARLOTTE BAG PIN...      1
# 1038  CHARLOTTE BAG SUKI DESIGN, WOODLAND CHARLOTTE BAG      1
# 1039  CHARLOTTE BAG SUKI DESIGN, CHARLOTTE BAG PINK ...      1
# 1040  CHARLOTTE BAG SUKI DESIGN, RED RETROSPOT CHARL...      1
# 1041                  HANGING HEART ZINC T-LIGHT HOLDER      1
# 1042                          CHARLOTTE BAG SUKI DESIGN      1
# 1043                            JUMBO BAG RED RETROSPOT      1
# 1044                             WOODLAND CHARLOTTE BAG      1
# 1045                        RED RETROSPOT CHARLOTTE BAG      1
# 1046                            LUNCH BAG PINK POLKADOT      1
# 1047                            LUNCH BAG RED RETROSPOT      1
# 1048                    ROSES REGENCY TEACUP AND SAUCER      1
# 1049                    GREEN REGENCY TEACUP AND SAUCER      1
# 1050                         ALARM CLOCK BAKELIKE GREEN      1
# 1051                            JUMBO BAG RED RETROSPOT      1
# 1052                                     DOTCOM POSTAGE      1
# 1053                         JUMBO BAG WOODLAND ANIMALS      1
# 1054                                     JUMBO BAG TOYS      1
#
# [1055 rows x 3 columns]

# %%
#============create label 0 rule=============

# get the items
items = basket.columns
no_repeat_items = list(set(items))
len(no_repeat_items)
# Out:
# 4175

# %%
no_repeat_items[:10]
# Out:
# ['add stock to allocate online orders',
#  'HANGING JAM JAR T-LIGHT HOLDER',
#  'QUEEN OF THE SKIES HOLIDAY PURSE',
#  'SET 10 CARDS WISHING TREE 17116',
#  'WALL ART VINTAGE HEART',
#  'MAGNETS PACK OF 4 VINTAGE LABELS',
#  '4 BURGUNDY WINE DINNER CANDLES',
#  'CERAMIC STRAWBERRY CAKE MONEY BANK',
#  'CITRUS GARLAND FELT FLOWERS',
#  'LUNCH BAG VINTAGE DOILEY']

# %%
def random_select(items):
    length = 2000
    all_a = []
    all_c = []
    
    for i in range(length):
        a_len = random.randint(0,1)
        c_len = random.randint(0,1)
        
        temp_a = []
        temp_c = []
        for j in range(a_len+1):
            item = random.choice(items)
            temp_a.append(item)
        for j in range(c_len+1):
            item = random.choice(items)
            temp_c.append(item)
            
        strtemp_a = ', '.join(temp_a)
        strtemp_c = ', '.join(temp_c)
        
        all_a.append(strtemp_a)
        all_c.append(strtemp_c)
        
    return all_a, all_c

# %%
all_a, all_c = random_select(no_repeat_items)

# %%
all_a[:10]
# Out:
# ['VINTAGE BILLBOARD MUG',
#  'COLOUR GLASS. STAR T-LIGHT HOLDER, FOLDING UMBRELLA WHITE/RED POLKADOT',
#  'LIGHT DECORATION BATTERY OPERATED, BLUE EGG  SPOON',
#  'YELLOW BREAKFAST CUP AND SAUCER',
#  'sold with wrong barcode',
#  'CLASSIC BICYCLE CLIPS',
#  'MINI PAINT SET VINTAGE',
#  '3 TIER SWEETHEART GARDEN SHELF',
#  'RED REFECTORY CLOCK',
#  'ZINC HEART FLOWER T-LIGHT HOLDER',
#  'BIRD ON BRANCH CANVAS SCREEN, CLEAR CRYSTAL STAR PHONE CHARM',
#  'BLUE/GREEN SHELL NECKLACE W PENDANT, BOTANICAL LILY GIFT WRAP',
#  'HEART OF WICKER LARGE, FRAPPUCINO SCARF KNITTING KIT',
#  'RABBIT EASTER DECORATION, SNACK TRAY RED GINGHAM',
#  "CRACKED GLAZE NECKLACE BROWN, MUM'S KITCHEN CLOCK",
#  'VINTAGE CREAM 3 BASKET CAKE STAND, RUSTIC STRAWBERRY JAM POT SMALL',
#  'SET OF 16 VINTAGE RED CUTLERY',
#  'DISCO BALL CHRISTMAS DECORATION, MONEY BOX FIRST ADE DESIGN',
#  'BOYS VINTAGE TIN SEASIDE BUCKET',
#  'MULTICOLOUR 3D BALLS GARLAND, WOVEN BUBBLE GUM CUSHION COVER',
#  'HANGING HEART MIRROR DECORATION, sold as set on dotcom',
#  'RED RETROSPOT BUTTER DISH, SET OF 2 TRAYS HOME SWEET HOME',
#  'FAUX FUR CHOCOLATE THROW',
#  'RED RETROSPOT CHARLOTTE BAG',
#  'SWISS ROLL TOWEL PINK  SPOTS',
#  'BEADED CRYSTAL HEART BLUE  LARGE',
#  'NUMBER TILE COTTAGE GARDEN 6, SNOWSTORM PHOTO FRAME FRIDGE MAGNET',
#  'LANDMARK FRAME NOTTING HILL',
#  'PACK OF 6 LARGE FRUIT STRAWS',
#  'CHERRY BLOSSOM DECORATIVE FLASK, ANGEL DECORATION STARS ON DRESS',
#  'BAKING SET 9 PIECE RETROSPOT',
#  'APOTHECARY MEASURING JAR, LADS ONLY TISSUE BOX',
#  'COFFEE SCENT PILLAR CANDLE, SMOKEY GREY COLOUR GLASS',
#  'PINK HEART SHAPE EGG FRYING PAN',
#  'VINTAGE  2 METER FOLDING RULER',
#  'DOG TOY WITH PINK CROCHET SKIRT',
#  'TREASURE AHOY WALL ART, TURQUOISE CRYSTAL+GLASS BRACELET',
#  'WOODEN HAPPY BIRTHDAY GARLAND',
#  'MINITURE ANTIQUE ROSE HOOK IVORY',
#  'GLASS APOTHECARY BOTTLE TONIC, BLUE CUSHION COVER WITH FLOWER',
#  'smashed',
#  'GREEN WIRE STANDING CANDLE HOLDER, ANTIQUE MID BLUE FLOWER EARRINGS',
#  'CHINESE DRAGON PAPER LANTERNS',
#  'BUTTERFLY CROCHET FOOD COVER',
#  'FELTCRAFT HAIRBAND RED AND BLUE, ZINC BOX SIGN HOME',
#  'WISE MAN STAR SHAPE EGG PAN, HANGING MEDINA LANTERN SMALL',
#  '6 ROCKET BALLOONS, 3 HOOK PHOTO SHELF ANTIQUE WHITE',
#  'DOILEY BISCUIT TIN, TEA PARTY  WRAPPING PAPER',
#  'MOROCCAN BEATEN METAL DISH',
#  'SET/3 POT PLANT CANDLES, LIGHTHOUSE PRINTED METAL SIGN',
#  'IVORY EMBROIDERED QUILT',
#  'FOOT STOOL HOME SWEET HOME',
#  'OLD DOC RUSSEL METAL SIGN',
#  'MUG , DOTCOMGIFTSHOP.COM, RED RETROSPOT BIG BOWL',
#  'GLASS JAR MARMALADE',
#  'POLYESTER FILLER PAD 60x40cm, HANGING CHICK CREAM DECORATION',
#  'GREETING CARD,SQUARE, DOUGHNUTS, PHOTO CUBE',
#  'VINTAGE UNION JACK SHOPPING BAG, CHAMPAGNE TRAY BLANK CARD',
#  'SMALL POLKADOT CHOCOLATE GIFT BAG',
#  'NATURAL SLATE HEART CHALKBOARD',
#  'RED RETROSPOT SHOPPING BAG',
#  'ZINC METAL HEART DECORATION, LANDMARK FRAME OXFORD STREET',
#  'WALL ART I LOVE LONDON',
#  'VINTAGE RED MUG',
#  'WOODEN UNION JACK BUNTING, SILVER RECORD COVER FRAME',
#  'LARGE DECO JEWELLERY STAND, RECYCLED PENCIL WITH RABBIT ERASER',
#  'LANDMARK FRAME LONDON BRIDGE, PINK BEADS+HAND PHONE CHARM',
#  'SMALL MARSHMALLOWS PINK BOWL',
#  'LARGE CAKE TOWEL CHOCOLATE SPOTS',
#  'YULETIDE IMAGES S/6 PAPER BOXES, PURPLE FINE BEAD NECKLACE W TASSEL',
#  'LUNCH BAG SUKI  DESIGN',
#  'check?, COLUMBIAN  CUBE CANDLE',
#  'SET OF 4 KNICK KNACK TINS DOILEY, CHOCOLATE HOT WATER BOTTLE',
#  'FIRE POLISHED GLASS BRACELET GREEN, CAKESTAND, 3 TIER, LOVEHEART',
#  'BREAD BIN DINER STYLE MINT',
#  'SET 10 CARDS 12 DAYS WRAP  17058, JUMBO BAG PAISLEY PARK',
#  'LARGE RED BABUSHKA NOTEBOOK, DOORMAT BLACK FLOCK',
#  'AMETHYST CHUNKY BEAD BRACELET W STR, JUMBO BAG RED RETROSPOT',
#  'Bank Charges',
#  'BLUE CUSHION COVER WITH FLOWER',
#  'CUTE CATS TAPE, KINGS CHOICE GIANT TUBE MATCHES',
#  'EGG CUP HENRIETTA HEN PINK',
#  'GOLD M.O.P ORBIT BRACELET',
#  'BLUE PAISLEY JOURNAL, 3D DOG PICTURE PLAYING CARDS',
#  'GENTLEMAN SHIRT REPAIR KIT',
#  'YELLOW METAL CHICKEN HEART',
#  'VINTAGE RED MUG, KINGS CHOICE MUG',
#  'wrongly coded 23343, TRAVEL CARD WALLET VINTAGE LEAF',
#  'KEY FOB , SHED, SPACE CADET RED',
#  'WALL ART BICYCLE SAFETY, ?missing',
#  'WHITE CHRISTMAS TREE 60CM',
#  'SUKI  SHOULDER BAG',
#  'SWISS ROLL TOWEL, CHOCOLATE  SPOTS, WINE BOTTLE DRESSING LT.BLUE',
#  'VINTAGE ENAMEL & CRYSTAL EARRINGS, CRYSTAL SEA HORSE PHONE CHARM',
#  'BOX OF 6 CHRISTMAS CAKE DECORATIONS',
#  'ALARM CLOCK BAKELIKE GREEN, FLOWER FAIRY 5 DRAWER LINERS',
#  'WAKE UP COCKEREL TILE HOOK',
#  'TOAST ITS - BEST MUM',
#  'BAKING MOULD EASTER EGG MILK CHOC, ORANGE/FUSCHIA STONES NECKLACE',
#  'incorrectly put back into stock, 12 PENCILS SMALL TUBE RED RETROSPOT',
#  'GLASS BON BON JAR, S/12 MINI RABBIT EASTER',
#  'SET OF 12 ROSE BOTANICAL T-LIGHTS',
#  'DAISY JOURNAL',
#  'AMAZON FEE',
#  'BLUE HOLE PUNCH',
#  'BEADED PEARL HEART WHITE ON STICK, DOORMAT WELCOME SUNRISE',
#  'EIGHT PIECE DINOSAUR SET',
#  'DECORATION  PINK CHICK MAGIC GARDEN',
#  'CD WALL TIDY BLUE OFFICE',
#  'EAU DE NIL LOVE BIRD CANDLE, CURIO CABINET LINEN AND LACE',
#  'SET OF 4 JAM JAR MAGNETS, FEATHER PEN,COAL BLACK',
#  'VINTAGE ZINC PLANTER, HEN PARTY CORDON BARRIER TAPE',
#  'CARD BILLBOARD FONT, PINK FELT HANGING HEART W FLOWER',
#  'WHITE TALL PORCELAIN T-LIGHT HOLDER, PINK MONTE CARLO HANDBAG',
#  'CHRISTMAS PUDDING TRINKET POT',
#  'GIFT BAG PSYCHEDELIC APPLES',
#  'WRAP PINK FAIRY CAKES, BIRD BOX CHRISTMAS TREE DECORATION',
#  'SET OF 36 MUSHROOM PAPER DOILIES, CANDLE HOLDER SILVER MADELINE',
#  'NEW BAROQUE BLACK BOXES',
#  'CHARLIE AND LOLA FIGURES TINS',
#  'BATHROOM SCALES, TROPICAL BEACH',
#  'Had been put aside., MARIE ANTOINETTE TRINKET BOX GOLD',
#  'PARTY METAL SIGN',
#  'PINK ROSEBUD PEARL EARRINGS, WHITE VINTAGE CRYSTAL EARRINGS',
#  'RED FLORAL FELTCRAFT SHOULDER BAG',
#  'SMALL YELLOW BABUSHKA NOTEBOOK, SET OF 4 NAPKIN CHARMS CUTLERY',
#  'SET 10 CARDS SNOWY SNOWDROPS  17100',
#  "WOODEN TREE CHRISTMAS SCANDINAVIAN, FLOWER FAIRY,5 SUMMER B'DRAW LINERS",
#  'PINK FAIRY CAKE CUSHION COVER',
#  'SET OF 2 TINS JARDIN DE PROVENCE',
#  'WRAP ALPHABET POSTER',
#  'COFFEE MUG PEARS  DESIGN',
#  'HEART WREATH DECORATION WITH BELL',
#  'IVORY WIRE KITCHEN ORGANISER',
#  'BAROQUE BUTTERFLY EARRINGS BLACK, WRAP RED APPLES',
#  'FUSCHIA VOILE POINTY SHOE DEC',
#  'PARTY PIZZA DISH BLUE POLKADOT',
#  'TRAVEL SEWING KIT',
#  'GYMKHANA TREASURE BOOK BOX, RASTA IN BATH W SPLIFF ASHTRAY',
#  'CARD SUKI BIRTHDAY',
#  'MINI JIGSAW DOLLY GIRL, thrown away',
#  'FOLDING BUTTERFLY MIRROR RED',
#  'GIFT BAG LARGE SPOT, BISCUITS SMALL BOWL LIGHT BLUE',
#  'GLASS BEAD HOOP NECKLACE MONTANA',
#  'CHILDRENS TOY COOKING UTENSIL SET',
#  'LARGE POPCORN HOLDER',
#  '200 BENDY SKULL STRAWS',
#  'BLUE & WHITE BREAKFAST TRAY',
#  'WRAP  VINTAGE DOILEY, TRADTIONAL ALPHABET STAMP SET',
#  'reverse previous adjustment, PARISIENNE CURIO CABINET',
#  'taig adjust no stock, LOVELY BONBON STICKER SHEET',
#  'DISCO BALL CHRISTMAS DECORATION',
#  'EASTER CRAFT 4 CHICKS',
#  'SET OF 6 KASHMIR FOLKART BAUBLES',
#  'TRADITIONAL KNITTING NANCY',
#  'GLASS  SONGBIRD STORAGE JAR',
#  'FENG SHUI PILLAR CANDLE, BLACK TEA TOWEL CLASSIC DESIGN',
#  'STAR WOODEN CHRISTMAS DECORATION',
#  'BLACK CRYSTAL DROP EARRINGS',
#  'PIN CUSHION BABUSHKA BLUE',
#  'BLACK DROP CRYSTAL NECKLACE',
#  'Dotcomgiftshop Gift Voucher £20.00, MIRROR MOSAIC VOTIVE HOLDER',
#  'PANDA AND BUNNIES STICKER SHEET',
#  'FOLDING CAMPING SCISSOR W/KNIF & S',
#  'CHRISTMAS CARD SCREEN PRINT',
#  'SNOWSTORM PHOTO FRAME FRIDGE MAGNET, KITTENS DESIGN FLANNEL',
#  'FOLKART CHRISTMAS TREE T-LIGHT HOLD',
#  'ASSORTED TUTTI FRUTTI NOTEBOOK, SILVER HEARTS TABLE DECORATION',
#  'SWISS CHALET TREE DECORATION, RATTLE SNAKE EGGS',
#  'FUSCHIA VOILE POINTY SHOE DEC, MIDNIGHT BLUE GLASS/SILVER BRACELET',
#  'BIRTHDAY CARD, RETRO SPOT',
#  'CHRISTMAS TREE HEART DECORATION, Found by jackie',
#  'BLACK LOVE BIRD T-LIGHT HOLDER, EMBROIDERED RIBBON REEL SOPHIE',
#  "JUMBO BAG 50'S CHRISTMAS, PINK PAPER PARASOL",
#  'Missing',
#  'CARD BILLBOARD FONT',
#  'TEA TIME TEAPOT IN GIFT BOX, PINK SCOTTIE DOG W FLOWER PATTERN',
#  'RED DAISY POCKET BOOK, DRAWER KNOB VINTAGE GLASS BALL',
#  'CANDY SPOT TEA COSY, AMBER GLASS TASSLE BAG CHARM',
#  'LARGE JEWELLERY STAND, FRENCH CARRIAGE LANTERN',
#  'WRAP DOLLY GIRL, damages/dotcom?',
#  'LUNCH BAG VINTAGE DOILY',
#  'PAIR OF PINK FLOWER CLUSTER SLIDE',
#  'PANTRY CHOPPING BOARD',
#  'ZINC HEART LATTICE T-LIGHT HOLDER',
#  'PURPLE ENAMEL FLOWER HAIR TIE, JUMBO BAG RED RETROSPOT',
#  'SET/6 BEAD COASTERS GAUZE BAG GOLD, FRIDGE MAGNETS LA VIE EN ROSE',
#  'STRAWBERRY CERAMIC TRINKET POT, OFFICE MUG WARMER PINK',
#  'GROW YOUR OWN BASIL IN ENAMEL MUG',
#  'WIRE FLOWER T-LIGHT HOLDER',
#  'GARDEN PATH SKETCHBOOK',
#  'AMETHYST CHUNKY BEAD BRACELET W STR, ENVELOPE 50 CURIOUS IMAGES',
#  'SET OF 3 WOODEN TREE DECORATIONS',
#  'VINTAGE KEEPSAKE BOX PARIS DAYS',
#  'FAIRY CAKES NOTEBOOK A6 SIZE, BOX OF 6 MINI VINTAGE CRACKERS',
#  'PINK POODLE HANGING DECORATION',
#  'FOUR RABBIT EASTER DECORATIONS, SKULLS SQUARE TISSUE BOX',
#  'SET 12 COLOUR PENCILS SPACEBOY',
#  'HOT WATER BOTTLE KEEP CALM',
#  'MULTICOLOUR POLKADOT PLATE, HERB MARKER THYME',
#  'LE JARDIN BOTANIQUE CUSHION COVER',
#  'ENAMEL DINNER PLATE PANTRY, HANGING CHICK GREEN DECORATION',
#  'SMALL POP BOX FUNKY MONKEY, SILVER DISCO HANDBAG',
#  'SET OF 16 VINTAGE PISTACHIO CUTLERY',
#  '18PC WOODEN CUTLERY SET DISPOSABLE',
#  'SOMBRERO',
#  'SKULL AND CROSSBONES  GARLAND',
#  'PAINT YOUR OWN CANVAS SET',
#  'SET 36 COLOUR PENCILS SPACEBOY',
#  'GREEN GLASS TASSLE BAG CHARM',
#  'PINK POLKADOT GARDEN PARASOL',
#  'RETROSPOT CANDLE  LARGE, STAR DECORATION PAINTED ZINC',
#  'SET OF 3 REGENCY CAKE TINS',
#  'missing?',
#  'ABSTRACT CIRCLES POCKET BOOK, CLASSIC WHITE FRAME',
#  'MINIATURE ANTIQUE ROSE HOOK IVORY, YELLOW METAL CHICKEN HEART',
#  'WRAP I LOVE LONDON, MAGNETS PACK OF 4 CHILDHOOD MEMORY',
#  'CERAMIC STRAWBERRY TRINKET TRAY',
#  'POLYESTER FILLER PAD 40x40cm',
#  "SMALL CERAMIC TOP STORAGE JAR, CLOCK MAGNET MUM'S KITCHEN",
#  'BLUE HANGING GINGHAM EASTER HEN, SMALL DECO JEWELLERY STAND',
#  'Lighthouse Trading zero invc incorr, PARTY CONE CHRISTMAS DECORATION',
#  'RETROSPOT CHILDRENS APRON, DOORMAT TOPIARY',
#  'GLASS BEAD HOOP NECKLACE AMETHYST',
#  "NEW BAROQUE B'FLY NECKLACE GREEN",
#  'SET 10 CARDS SWIRLY XMAS TREE 17104, KNEELING MAT HOUSEWORK  DESIGN',
#  '75 BLACK PETIT FOUR CASES, BEADED LOVE HEART JEWELLERY SET',
#  'COFFEE MUG CAT + BIRD DESIGN',
#  'PURPLE BOUDICCA LARGE BRACELET, PINK POLKADOT CHILDRENS UMBRELLA',
#  'PINK/WHITE CHRISTMAS TREE 30CM',
#  'CUT GLASS T-LIGHT HOLDER OCTAGON',
#  'MIRROR MOSAIC T-LIGHT HOLDER ROUND',
#  'CAMOUFLAGE DESIGN TEDDY, FRAPPUCINO SCARF KNITTING KIT',
#  'SET OF 6 T-LIGHTS TOADSTOOLS',
#  'IVORY EMBROIDERED QUILT',
#  'JUMBO BAG RED RETROSPOT, JUMBO BAG STRAWBERRY',
#  'sold as 22467, 72 CAKE CASES VINTAGE CHRISTMAS',
#  'HOME SWEET HOME MUG, STRAWBERRY LUNCH BOX WITH CUTLERY',
#  'SET OF 6 NATIVITY MAGNETS',
#  'STRAWBERRY CERAMIC TRINKET POT, SET OF 9 HEART SHAPED BALLOONS',
#  'JUMBO BAG VINTAGE DOILY, PINK BABY BUNTING',
#  'RETROSPOT CANDLE  SMALL, CARDHOLDER GINGHAM CHRISTMAS TREE',
#  'MIDNIGHT BLUE GLASS/SILVER BRACELET, BROWN VINTAGE VICTORIAN EARRINGS',
#  'CHINESE DRAGON PAPER LANTERNS, KEEP CALM BIRTHDAY WRAP',
#  'WOODEN PICTURE FRAME WHITE FINISH, PURPLE CRYSTAL DROP EARRINGS',
#  'ORIGAMI ROSE INCENSE/CANDLE SET, 36 PENCILS TUBE SKULLS',
#  'WRAP ALPHABET POSTER, PINK PAISLEY SQUARE TISSUE BOX',
#  'ANTIQUE HEART SHELF UNIT',
#  'EGG FRYING PAN RED, STAR WREATH DECORATION WITH BELL',
#  'WHITE ENAMEL FLOWER HAIR TIE, OPIUM SCENTED VOTIVE CANDLE',
#  'JUMBO BAG VINTAGE DOILEY',
#  'PANTRY ROLLING PIN, COSY HOUR GIANT TUBE MATCHES',
#  'EASTER DECORATION HANGING BUNNY, label mix up',
#  'JIGSAW TREE WITH WATERING CAN, SET OF 4 NAPKIN CHARMS STARS',
#  'S/6 SEW ON CROCHET FLOWERS',
#  'DECORATION WOBBLY RABBIT METAL',
#  'LETTER "Z" BLING KEY RING, GLASS AND PAINTED BEADS BRACELET OL',
#  'RUSTIC  SEVENTEEN DRAWER SIDEBOARD',
#  'MINI WOODEN HAPPY BIRTHDAY GARLAND, EMBROIDERED RIBBON REEL ROSIE',
#  'SUNSET COLOUR CHUNKY KNITTED THROW',
#  'RED RETROSPOT CUP, HEART TRELLIS TRIPLE T-LIGHT HOLDER',
#  'HEART GARLAND RUSTIC PADDED',
#  'LAUREL HEART ANTIQUE GOLD, CHEST 7 DRAWER MA CAMPAGNE',
#  'ASSORTED COLOUR LIZARD SUCTION HOOK',
#  'ALARM CLOCK BAKELIKE CHOCOLATE, TEA TIME KITCHEN APRON',
#  'PORCELAIN ROSE SMALL, CERAMIC STRAWBERRY MONEY BOX',
#  'ENAMEL WATERING CAN CREAM',
#  'NEW BAROQUE BLACK BOXES, JOY LARGE WOOD LETTERS',
#  'KEY FOB , FRONT  DOOR',
#  'SET OF 2 TEA TOWELS PING MICROWAVE',
#  'LARGE HEART FLOWERS HOOK',
#  'TUMBLER BAROQUE',
#  'PINK DAISY BAG CHARM',
#  'CREAM SWEETHEART WALL CABINET',
#  'BLUE HAPPY BIRTHDAY BUNTING, CHRISTMAS STAR WISH LIST CHALKBOARD',
#  'PACK OF 60 MUSHROOM CAKE CASES, BLUE SCOTTIE DOG W FLOWER PATTERN',
#  'ORGANISER WOOD ANTIQUE WHITE, RED SPOT CERAMIC DRAWER KNOB',
#  'HANGING CHICK GREEN DECORATION',
#  'FIVE CATS HANGING DECORATION',
#  'GLITTER HANGING BUTTERFLY STRING',
#  'EGG FRYING PAN MINT',
#  '????damages????',
#  'NUMBER TILE COTTAGE GARDEN 8, VINTAGE RED ENAMEL TRIM PLATE',
#  'PINK HORSE SOCK PUPPET, BLACK VINT ART DEC CRYSTAL BRACELET',
#  'DAIRY MAID STRIPE MUG',
#  'CHRISTMAS CRAFT TREE TOP ANGEL',
#  'PORCELAIN ROSE LARGE',
#  'COUNTRY COTTAGE  DOORSTOP GREEN, QUEEN OF SKIES LUGGAGE TAG',
#  'WOOD 2 DRAWER CABINET WHITE FINISH, SET OF 4 NAPKIN CHARMS CUTLERY',
#  'CHRISTMAS HANGING HEART WITH BELL, KEEP CALM WALL ART',
#  'PAPER BUNTING COLOURED LACE',
#  'GLASS BEAD HOOP EARRINGS AMETHYST',
#  'EMBROIDERED RIBBON REEL REBECCA, BROWN VINTAGE VICTORIAN EARRINGS',
#  'LILY BROOCH AMETHYST COLOUR',
#  'MINI JIGSAW GO TO THE FAIR',
#  'ZINC STAR T-LIGHT HOLDER',
#  'PET MUG, GOLDFISH',
#  'PARTY INVITES DINOSAURS',
#  'FLORAL BLUE MONSTER',
#  'SOFT PINK ROSE TOWEL',
#  'TRANQUILITY MASALA INCENSE, WALL ART DOG AND BALL',
#  'CRYSTAL SEA HORSE PHONE CHARM, PACK OF 12 VINTAGE CHRISTMAS TISSUE',
#  'POLYESTER FILLER PAD 45x45cm',
#  'HANGING  BUTTERFLY T-LIGHT HOLDER, MILK MAIDS MUG',
#  'FELTCRAFT HAIRBAND RED AND BLUE',
#  'SET OF 10 LANTERNS FAIRY LIGHT STAR, SET/3 CHRISTMAS DECOUPAGE CANDLES',
#  'MAXWELL 2 TONE BLUE 60 PAGE PHOTO A',
#  'ROSE DU SUD WASHBAG',
#  'SPRIG LAVENDER ARTIFICIAL FLOWER',
#  'FUSCHIA TABLE RUN FLOWER',
#  'VICTORIAN  METAL POSTCARD SPRING',
#  'ASSORTED FARMYARD ANIMALS IN BUCKET',
#  'S/3 POT POURI CUSHIONS BLUE COLOURS, GARLAND WITH STARS AND BELLS',
#  'PACK OF 20 NAPKINS RED APPLES',
#  'LOVE LARGE WOOD LETTERS, PORCELAIN ROSE LARGE',
#  "Dr. Jam's Arouzer Stress Ball",
#  'RED VINTAGE SPOT BEAKER, SET 10 CARDS TRIANGLE ICONS  17220',
#  'TRIANGULAR POUFFE VINTAGE, GREEN WITH METAL BAG CHARM',
#  'SET/5 RED RETROSPOT LID GLASS BOWLS, SILVER BLACK ORBIT DROP EARRINGS',
#  'sold as set/6 by dotcom',
#  'LANDMARK FRAME OXFORD STREET, DRAWER KNOB VINTAGE GLASS HEXAGON',
#  'OOH LA LA DOGS COLLAR',
#  'CHILDRENS GARDEN GLOVES PINK',
#  'NUMBER TILE COTTAGE GARDEN 4',
#  'GOLD M.O.P. ORBIT NECKLACE',
#  'POTTERING IN THE SHED METAL SIGN, RAINY LADIES BIRTHDAY CARD',
#  'ROSE DU SUD WASHBAG, OFFICE MUG WARMER PINK',
#  'TROPICAL LUGGAGE TAG, SMALL ZINC HEART WALL ORGANISER',
#  'S/4 CACTI CANDLES',
#  'wrongly sold (22719) barcode, FLOWER FAIRY 5 DRAWER LINERS',
#  'HANGING METAL RABBIT DECORATION',
#  'ANTIQUE SILVER TEA GLASS ENGRAVED',
#  'DECORATION  BUTTERFLY  MAGIC GARDEN',
#  'Printing smudges/thrown away, RAIN PONCHO',
#  'CAT AND BIRD WALL ART',
#  'SILVER  CANDLEPOT JARDIN, COLUMBIAN CUBE CANDLE',
#  'RED RETROSPOT WASHBAG',
#  'WHITE VINTAGE CRYSTAL EARRINGS, BASKET OF TOADSTOOLS',
#  'ASS FLORAL PRINT SPIRIT LEVEL, FLAG OF ST GEORGE',
#  'SWEETHEART WIRE FRUIT BOWL, RECYCLING BAG RETROSPOT',
#  'SILVER HEARTS TABLE DECORATION',
#  'SET OF 36 DOILIES PANTRY DESIGN',
#  'LARGE TAHITI BEACH BAG, SILVER/MOP ORBIT NECKLACE',
#  'FRENCH CARRIAGE LANTERN',
#  'STRING OF STARS CARD HOLDER',
#  'SET OF 6 3D KIT CARDS FOR KIDS',
#  '?lost, MONEY BOX CONFECTIONERY DESIGN',
#  'water damaged',
#  'SET OF 3 WOODEN TREE DECORATIONS',
#  'SET 3 SONG BIRD PAPER EGGS ASSORTED, STRAWBERRY DREAM CHILDS UMBRELLA',
#  'PINK KNITTED EGG COSY, WICKER WREATH LARGE',
#  'PEACH KNITTED HEN, HANGING WOOD AND FELT FLOWER',
#  '4 SKY BLUE DINNER CANDLES',
#  'WHITE TRAVEL ALARM CLOCK',
#  'TV DINNER TRAY DOLLY GIRL',
#  'SET OF 3 WOODEN STOCKING DECORATION, GARDEN METAL SIGN',
#  'WAKE UP COCKEREL TILE COASTER',
#  'SWEETHEART CERAMIC TRINKET BOX',
#  'BLACK STITCHED WALL CLOCK',
#  'LUNCH BAG  BLACK SKULL.',
#  'CARDHOLDER HOLLY WREATH METAL, CERAMIC LOVE HEART MONEY BANK',
#  'SET/3 DECOUPAGE STACKING TINS, GOLD COSMETIC BAG PINK STAR',
#  'rusty thrown away',
#  'FROSTED WHITE BASE',
#  'GOLD PRINT PAPER BAG',
#  'HAND WARMER BABUSHKA DESIGN',
#  'JIGSAW TREE WITH WATERING CAN',
#  'PAPER CHAIN KIT LONDON',
#  'WRAP MAGIC FOREST',
#  'ROUND SNACK BOXES SET OF 4 FRUITS, LONDON BUS COFFEE MUG',
#  'FRIDGE MAGNETS US DINER ASSORTED',
#  'PICTURE DOMINOES, CHILDRENS APRON APPLES DESIGN',
#  'BANQUET BIRTHDAY  CARD',
#  '60 CAKE CASES VINTAGE CHRISTMAS',
#  'RETRO LONGBOARD IRONING BOARD COVER, ANGEL DECORATION WITH LACE PADDED',
#  'BLACK GEMSTONE NECKLACE 45CM',
#  'BLACK ENCHANTED FOREST PLACEMAT, GINGHAM HEART  DOORSTOP RED',
#  'SILVER M.O.P ORBIT DROP EARRINGS, MONEY BOX FIRST ADE DESIGN',
#  'CERAMIC CAKE STAND + HANGING CAKES, ????damages????',
#  'YELLOW FELT HANGING HEART W FLOWER',
#  'WATERMELON BATH SPONGE, CHILDRENS GARDEN GLOVES BLUE',
#  'SMALL POLKADOT CHOCOLATE GIFT BAG, ASSORTED TUTTI FRUTTI SMALL PURSE',
#  'NEW ENGLAND MUG W GIFT BOX, METAL SIGN,CUPCAKE SINGLE HOOK',
#  'DOORMAT HOME SWEET HOME BLUE, CHILDS GARDEN RAKE BLUE',
#  'SET OF 36 PAISLEY FLOWER DOILIES',
#  'GOLD/M.O.P PENDANT ORBIT NECKLACE, STRAWBERRY BATH SPONGE',
#  'PSYCHEDELIC METAL SIGN CALENDAR, QUEEN OF THE SKIES PASSPORT COVER',
#  'JIGSAW TREE WITH BIRDHOUSE',
#  'SET OF 6 T-LIGHTS CACTI, dotcomstock',
#  'REX CASH+CARRY JUMBO SHOPPER',
#  'GOLD DIAMANTE STAR BROOCH, HANGING HEN ON NEST DECORATION',
#  'GREEN POLKADOT PLATE, UNION JACK HOT WATER BOTTLE',
#  'LETTER "A" BLING KEY RING',
#  'TRAVEL CARD WALLET KEEP CALM, SMALL CHINESE STYLE SCISSOR',
#  'SMALL PINK MAGIC CHRISTMAS TREE, SILVER ROCCOCO CHANDELIER',
#  '3 WHITE CHOC MORRIS BOXED CANDLES',
#  'FIRE POLISHED GLASS BRACELET MONTAN',
#  'ZINC T-LIGHT HOLDER STARS LARGE',
#  'SMALL PARLOUR FRAME',
#  'WOODEN TREE CHRISTMAS SCANDINAVIAN, found some more on shelf',
#  'GREEN EASTER EGG HUNT START POST, PINK/GREEN FLOWER DESIGN BIG MUG',
#  'MULTICOLOUR EASTER RABBIT',
#  'HOME SWEET HOME METAL SIGN',
#  'WOODLAND LARGE BLUE FELT HEART',
#  'FELTCRAFT PRINCESS LOLA DOLL',
#  'VINTAGE UNION JACK CUSHION COVER',
#  'JUMBO BAG SCANDINAVIAN PAISLEY, HANGING SPRING FLOWER EGG SMALL',
#  'LIPSTICK PEN BABY PINK, POLYESTER FILLER PAD 40x40cm',
#  'NUMBER TILE COTTAGE GARDEN 4, FRYING PAN BLUE POLKADOT',
#  'GREY FLORAL FELTCRAFT SHOULDER BAG, CHICK GREY HOT WATER BOTTLE',
#  'TRELLIS COAT RACK, SMALL HAMMERED SILVER CANDLEPOT',
#  'PACK OF 12 TRADITIONAL CRAYONS, PURPLE FOXGLOVE ARTIIFCIAL FLOWER',
#  'NUMBER TILE VINTAGE FONT 8',
#  'TRAVEL CARD WALLET VINTAGE TICKET',
#  'PINK SWEETHEART BRACELET',
#  'NEW BAROQUE BLACK BOXES',
#  'BAROQUE BUTTERFLY EARRINGS BLACK, DOLLY GIRL CHILDRENS EGG CUP',
#  'WRAP KEEP CALM BIRTHDAY, 36 DOILIES DOLLY GIRL',
#  'CHICK GREY HOT WATER BOTTLE, WHITE CHRISTMAS GARLAND STARS TREES',
#  'PINK/WHITE GLASS DEMI CHOKER',
#  'CHILDRENS CUTLERY POLKADOT BLUE, BLACK BAROQUE WALL CLOCK',
#  'DOLLY GIRL MINI BACKPACK',
#  'SILICON STAR BULB  BLUE, JUMBO BAG OWLS',
#  'YELLOW FLOWERS FELT HANDBAG KIT, SILVER JEWELLED MIRROR TRINKET TRAY',
#  'SET/3 POT PLANT CANDLES, BLUE HARMONICA IN BOX',
#  'FAIRY CAKES NOTEBOOK A6 SIZE, PACK OF 12 CIRCUS PARADE TISSUES',
#  'FELTCRAFT CUSHION RABBIT, LETTER "N" BLING KEY RING',
#  "NURSE'S BAG SOFT TOY, WRAP RED DOILEY",
#  'FRENCH BLUE METAL DOOR SIGN 1',
#  'SWEETIES  STICKERS',
#  'BUNNY EGG GARLAND, IVY HEART WREATH',
#  'DOORMAT VINTAGE LEAF',
#  'FIRE POLISHED GLASS BRACELET BLACK, FAIRY DREAMS INCENSE',
#  'FRENCH ENAMEL WATER BASIN',
#  'CLEAR CRYSTAL STAR PHONE CHARM, PAPER LANTERN 9 POINT HOLLY STAR 40',
#  'CANDY SPOT CUSHION COVER',
#  "NEW BAROQUE B'FLY NECKLACE PINK",
#  'LUSH GREENS RIBBONS, SET OF 36 PAISLEY FLOWER DOILIES',
#  'CARD DOLLY GIRL',
#  'FLOWER FAIRY 5 SUMMER DRAW LINERS',
#  'PHOTO CUBE',
#  'AMBER CHUNKY BEAD BRACELET W STRAP',
#  'SET 6 PAPER TABLE LANTERN HEARTS',
#  'SET OF TEA COFFEE SUGAR TINS PANTRY',
#  'FOLDING UMBRELLA RED/WHITE POLKADOT, VINTAGE BEAD PINK SHADE',
#  'PINK LOVE HEART SHAPE CUP',
#  'GLITTER HANGING BUTTERFLY STRING',
#  'WHITE HYDRANGEA ART FLOWER',
#  'John Lewis, ANT COPPER LIME BOUDICCA BRACELET',
#  'BLACK BAROQUE CARRIAGE CLOCK, RED STRIPE CERAMIC DRAWER KNOB',
#  'BEADED CRYSTAL HEART GREEN ON STICK, PAPER LANTERN 9 POINT HOLLY STAR 23',
#  'incorrectly credited C550456 see 47, CHARLOTTE BAG DOLLY GIRL DESIGN',
#  'PINK  HEART SHAPE LOVE BUCKET, SET OF 2 TINS VINTAGE BATHROOM',
#  'RED REFECTORY CLOCK, SMALL HEART MEASURING SPOONS',
#  'FLOWER GLASS GARLAND NECKL.36"BLACK',
#  'WRAP MAGIC FOREST',
#  'TRAVEL CARD WALLET VINTAGE TICKET',
#  'DOORSTOP FOOTBALL DESIGN',
#  'METAL SIGN NEIGHBOURHOOD WITCH',
#  'GOLDIE LOOKING MIRROR, RED POLKADOT PUDDING BOWL',
#  'BLUE EGG  SPOON, NUMBER TILE COTTAGE GARDEN 9',
#  'RETROSPOT WOODEN HEART DECORATION, REINDEER HEART DECORATION GOLD',
#  'BABY MOUSE RED GINGHAM DRESS, TEATIME PEN CASE & PENS',
#  'HEART BUTTONS JEWELLERY BOX, STRIPES DESIGN TEDDY',
#  'BLUE  DIAMANTE PEN IN GIFT BOX, CREAM FELT EASTER EGG BASKET',
#  'VINTAGE PAISLEY STATIONERY SET',
#  'GYMKHANA TREASURE BOOK BOX, VIPPASSPORT COVER',
#  'VICTORIAN  METAL POSTCARD SPRING',
#  'VINTAGE EMBOSSED HEART',
#  'WRAP CIRCUS PARADE, MILK BOTTLE WITH GLASS STOPPER',
#  'CIRCUS PARADE BABY GIFT SET, POCKET BAG BLUE PAISLEY RED SPOT',
#  'MOODY BOY  DOOR HANGER, CANNISTER VINTAGE LEAF DESIGN',
#  'GINGERBREAD MAN COOKIE CUTTER, MIRRORED DISCO BALL',
#  '3 BIRDS CANVAS SCREEN',
#  'RED SPOT GIFT BAG LARGE',
#  'SET 10 CARDS 12 DAYS OF XMAS 17059, PACK OF 12 RED RETROSPOT TISSUES',
#  'HANGING HEN ON NEST DECORATION, BUTTON BOX',
#  'LE GRAND TRAY CHIC SET, DRAWER KNOB CRACKLE GLAZE BLUE',
#  'HOUSE WRECKING METAL SIGN',
#  'DOORMAT PEACE ON EARTH BLUE, WOVEN FROST CUSHION COVER',
#  '60 GOLD AND SILVER FAIRY CAKE CASES, IVORY WIRE KITCHEN ORGANISER',
#  'CARD BIRTHDAY COWBOY',
#  'BLUE HAPPY BIRTHDAY BUNTING, SET OF 3 NOTEBOOKS IN PARCEL',
#  'PACK OF 20 SKULL PAPER NAPKINS',
#  'JUMBO BAG STRAWBERRY, CROCHET WHITE RABBIT KEYRING',
#  'ROCKING HORSE RED CHRISTMAS, PURPLE FINE BEAD NECKLACE W TASSEL',
#  'faulty, SET 10 CARDS RED RIDING HOOD 17214',
#  'PACK OF 60 MUSHROOM CAKE CASES',
#  'WALL ART ,PUDDINGS',
#  "FANNY'S REST STOPMETAL SIGN",
#  'FILIGREE DIAMANTE EARRINGS',
#  'FLORAL PINK MONSTER, FOLK FELT HANGING MULTICOL GARLAND',
#  'SILK PURSE BABUSHKA BLUE, PINK/PURPLE CIRCLE CURTAIN',
#  'ASSORTED TUTTI FRUTTI LARGE PURSE, WOODEN REGATTA BUNTING',
#  'CORDIAL GLASS JUG',
#  'code mix up? 84930',
#  'MUMMY MOUSE RED GINGHAM RIBBON',
#  'TRELLIS COAT RACK',
#  'STAR WOODEN CHRISTMAS DECORATION, PINK CAT BOWL',
#  'MAGAZINE RACK GEBRA ASSORTED, POLYESTER FILLER PAD 30CMx30CM',
#  'GARDEN METAL SIGN',
#  'CAPIZ CHANDELIER',
#  'PLAYING CARDS VINTAGE DOILEY, VINTAGE KEEPSAKE BOX PINK FLOWER',
#  'SET 10 CARDS HATS & STOCKINGS 17081, FAIRY TALE COTTAGE NIGHTLIGHT',
#  'check, CAROUSEL DESIGN WASHBAG',
#  'VINTAGE LEAF CHOPPING BOARD, LOLITA  DESIGN  COTTON TOTE BAG',
#  'S/15 SILVER GLASS BAUBLES IN BAG, REGENCY CAKE FORK',
#  'HANGING BAUBLE T-LIGHT HOLDER LARGE',
#  'NUMBER TILE VINTAGE FONT 7',
#  'EASTER TIN CHICKS PINK DAISY',
#  'STORAGE TIN VINTAGE DOILEY',
#  'METAL SIGN TAKE IT OR LEAVE IT, HEART TRELLIS TRIPLE T-LIGHT HOLDER',
#  'BLUE TV TRAY TABLE',
#  'BLUE PATCH PURSE PINK HEART',
#  'SET/4 BADGES BALLOON GIRL, THE KING GIFT BAG 25x24x12cm',
#  'SMALL PARISIENNE HEART PHOTO FRAME',
#  '50CM METAL STRING WITH  7 CLIPS',
#  'LADLE LOVE HEART PINK, SET/2 RED RETROSPOT TEA TOWELS',
#  '3 WICK CHRISTMAS BRIAR CANDLE, HANGING HEART JAR T-LIGHT HOLDER',
#  'COCKTAIL SWORDS 50 PIECES',
#  'PSYCHEDELIC TILE HOOK',
#  'SET/4 SPRING FLOWER DECORATION',
#  'LETTER "G" BLING KEY RING, HEART MIRROR ANTIQUE WHITE',
#  'TEATIME FUNKY FLOWER BACKPACK FOR 2',
#  'AMETHYST HOOP EARRING FLORAL LEAF, NECKLACE+BRACELET PINK BUTTERFLY',
#  '6 RIBBONS ELEGANT CHRISTMAS',
#  'ECONOMY HOLIDAY PURSE',
#  'ANTIQUE SILVER BOOK MARK WITH BEADS',
#  'LARGE TAHITI BEACH BAG, S/12 VANILLA  BOTANICAL T-LIGHTS',
#  'DIAMANTE NECKLACE',
#  'wrongly coded 23343, ORIGAMI OPIUM INCENSE/CANDLE SET',
#  'JUMBO BAG SCANDINAVIAN PAISLEY, WHITE CHRISTMAS GARLAND STARS TREES',
#  'GREEN STONE/CRYSTAL EARRINGS, ZINC SWEETHEART WIRE LETTER RACK',
#  'JUMBO BAG RED RETROSPOT, CLEAR STATIONERY BOX SET',
#  'CHRISTMAS PUDDING TRINKET POT',
#  'GIFT BAG LARGE SPOT, FRENCH BLUE METAL DOOR SIGN 1',
#  '36 FOIL HEART CAKE CASES, LETTER "U" BLING KEY RING',
#  'FOLKART ZINC HEART CHRISTMAS DEC',
#  'SET 6 PAPER TABLE LANTERN HEARTS, CERAMIC CAKE BOWL + HANGING CAKES',
#  'CONGRATULATIONS BUNTING',
#  'RED CHARLIE+LOLA PERSONAL DOORSIGN',
#  'MIRROR MOSAIC GOBLET CANDLE HOLDER',
#  'GOLD TEDDY BEAR, WHITE/PINK CHICK EASTER DECORATION',
#  'PACK OF 12 HEARTS DESIGN TISSUES',
#  'ACRYLIC HANGING JEWEL,BLUE',
#  'STRAWBERRY DREAM CHILDS UMBRELLA, LIPSTICK PEN RED',
#  'SCOTTIE DOGS BABY BIB, CUT GLASS T-LIGHT HOLDER OCTAGON',
#  'SQUARE MINI PORTRAIT FRAME, PINK FEATHER CHRISTMAS DECORATION',
#  'MINT DINER WALL CLOCK, WHITE TISSUE REAM',
#  'WIRE FLOWER T-LIGHT HOLDER',
#  'WOODLAND SMALL RED FELT HEART',
#  'COFFEE MUG PINK PAISLEY DESIGN, PINK OWL SOFT TOY',
#  'TEA TIME TEA SET IN GIFT BOX, JUMBO STORAGE BAG SKULLS',
#  'MIRROR MOSAIC T-LIGHT HOLDER',
#  'FLORAL BLUE MONSTER',
#  'HOME SWEET HOME 3 PEG HANGER',
#  'RED RETROSPOT LUGGAGE TAG, CARD CAT AND TREE',
#  'GREEN/BLUE CERAMIC CANDLE HOLDER, ZINC METAL HEART DECORATION',
#  'METAL SIGN HER DINNER IS SERVED, SET OF 16 VINTAGE RED CUTLERY',
#  'PANTRY HOOK TEA STRAINER',
#  'PURPLE FRANGIPANI NECKLACE, FRYING PAN PINK POLKADOT',
#  'HANGING WOOD AND FELT BUTTERFLY, SET OF 4 ROSE BOTANICAL CANDLES',
#  'CROCHET LILAC/RED BEAR KEYRING, PINK EASTER HENS+FLOWER',
#  'BALLOONS  WRITING SET, WHITE WIRE PLANT POT HOLDER',
#  'DANISH ROSE ROUND SEWING BOX',
#  'SPACE CADET WHITE, SET/3 OCEAN SCENT CANDLE JEWEL BOX',
#  'AMBER BERTIE GLASS BEAD BAG CHARM',
#  'ZINC WIRE SWEETHEART LETTER TRAY, ABSTRACT CIRCLE JOURNAL',
#  'DINOSAUR HEIGHT CHART STICKER SET, CRYSTAL PAIR HEART HAIR SLIDES',
#  'AMAZON',
#  'SET/3 POT PLANT CANDLES, PINK BUNNY EASTER EGG BASKET',
#  'RED LOVE HEART SHAPE CUP, PINK FLOWER CROCHET FOOD COVER',
#  'PAINTED SEA SHELL METAL WINDCHIME, FIRE POLISHED GLASS BRACELET MONTAN',
#  'BLACK WINE GLASS, PURPLE BOUDICCA LARGE BRACELET',
#  'WOODLAND  HEIGHT CHART STICKERS, CREAM WALL PLANTER HEART SHAPED',
#  'FOLDING BUTTERFLY MIRROR HOT PINK, IVORY RETRO KITCHEN WALL CLOCK',
#  'Missing',
#  'S/12 VANILLA  BOTANICAL T-LIGHTS, FROG KING WATERING CAN',
#  'TV DINNER TRAY AIR HOSTESS, COSY HOUR GIANT TUBE MATCHES',
#  'FRIDGE MAGNETS LES ENFANTS ASSORTED, CERAMIC HEART FAIRY CAKE MONEY BANK',
#  'TOAST ITS - HAPPY BIRTHDAY',
#  'LAUREL STAR ANTIQUE GOLD',
#  'ORANGE/WHT/FUSCHIA STONES NECKLACE',
#  'FELTCRAFT DOLL MARIA',
#  'RETRO LONGBOARD IRONING BOARD COVER, BLUE POLKADOT WRAP',
#  'ANTIQUE HEART SHELF UNIT, HOME SWEET HOME METAL SIGN',
#  'DARK BIRD HOUSE TREE DECORATION',
#  'CHRISTMAS CRAFT TREE TOP ANGEL',
#  'SQUARE FLOOR CUSHION VINTAGE RED, FAIRY TALE COTTAGE NIGHTLIGHT',
#  'ABSTRACT CIRCLES SKETCHBOOK, CHERUB HEART DECORATION GOLD',
#  'AMBER 3 BEAD DROP EARRINGS, Adjust bad debt',
#  'DOORMAT WELCOME SUNRISE, VINTAGE CHRISTMAS STOCKING',
#  'S/4 GROOVY CAT MAGNETS, WOODEN FRAME ANTIQUE WHITE',
#  'SET OF 6 VINTAGE NOTELETS KIT',
#  'SET OF 3 WOODEN HEART DECORATIONS',
#  'FRENCH BLUE METAL DOOR SIGN 2',
#  'ROBOT MUG IN DISPLAY BOX, TEA TIME KITCHEN APRON',
#  'FOOT STOOL HOME SWEET HOME',
#  'SET OF THREE VINTAGE GIFT WRAPS',
#  'TUMBLER, NEW ENGLAND',
#  'VINTAGE BEAD NOTEBOOK, MARIE ANTOINETTE TRINKET BOX GOLD',
#  'SET OF 2 TEA TOWELS PING MICROWAVE',
#  'TRAVEL CARD WALLET TRANSPORT, ASSORTED COLOUR SUCTION CUP HOOK',
#  'VINTAGE RED ENAMEL TRIM PLATE',
#  'IVORY SHELL HEART EARRINGS, found some more on shelf',
#  'HANGING CHICK GREEN DECORATION',
#  'RIDGED BONNE JAM JAR T-LIGHT HOLDER, COSY HOUR GIANT TUBE MATCHES',
#  'TIGRIS EYE CHUNKY CHARM BRACELET, EGG FRYING PAN BLUE',
#  'TRAVEL CARD WALLET VINTAGE ROSE, METAL SIGN NEIGHBOURHOOD WITCH',
#  'FOOD/DRINK SPONGE STICKERS, CHINESE DRAGON PAPER LANTERNS',
#  'PAINTED SEA SHELL METAL WINDCHIME, SET OF 4 CAROUSEL PLACEMATS',
#  'CAT BOWL VINTAGE CREAM, MINI JIGSAW BAKE A CAKE',
#  'HYACINTH BULB T-LIGHT CANDLES, WOODEN SKITTLES GARDEN SET',
#  'ANT SILVER LIME GREEN BOUDICCA RING',
#  'JIGSAW RABBIT AND BIRDHOUSE, PINK FEATHERS CURTAIN',
#  'PAPER CHAIN KIT LONDON, RETRO TIN ASHTRAY,REVOLUTIONARY',
#  'HEART CALCULATOR',
#  'ENAMEL WATERING CAN CREAM',
#  'Dotcom sales, FOLKART ZINC STAR CHRISTMAS DEC',
#  "ROLL WRAP 50'S CHRISTMAS, BOUDOIR SQUARE TISSUE BOX",
#  'CUBIC MUG FLOCK PINK ON BROWN, PAPER BUNTING COLOURED LACE',
#  'CRYSTAL DIAMANTE STAR BROOCH',
#  'COSY HOUR GIANT TUBE MATCHES, SET/20 FRUIT SALAD PAPER NAPKINS',
#  'FIVE HEART HANGING DECORATION, RETRO MOD TRAY',
#  'RED KUKUI COCONUT SEED NECKLACE, on cargo order',
#  'CLEAR MILKSHAKE GLASS',
#  'RED RETROSPOT WRAP, AMETHYST DROP EARRINGS W LONG BEADS',
#  'TRANQUILITY MASALA INCENSE',
#  'DOORSTOP RACING CAR DESIGN',
#  'HOME BUILDING BLOCK WORD, VINYL RECORD FRAME SILVER',
#  'wrongly sold sets, HANGING FAIRY CAKE DECORATION',
#  'LETTER "N" BLING KEY RING, BLUE POLKADOT COFFEE MUG',
#  'PINK PILLAR CANDLE SILVER FLOCK, COSY HOUR GIANT TUBE MATCHES',
#  'JET BLACK LAS VEGAS BRACELET ROUND, PINK GLASS CANDLEHOLDER',
#  'VINTAGE KITCHEN PRINT VEGETABLES',
#  'SUKI  SHOULDER BAG',
#  'MEDIUM WHITE/PINK ROSE ART FLOWER, REGENCY TEA PLATE PINK',
#  'CHILDRENS APRON APPLES DESIGN, SET OF 4 PISTACHIO LOVEBIRD COASTER',
#  'DRAWER KNOB VINTAGE GLASS STAR, VINTAGE ENAMEL & CRYSTAL EARRINGS',
#  'SMALL DECO JEWELLERY STAND, 3 PINK HEN+CHICKS IN BASKET',
#  'CURIOUS  IMAGES NOTEBOOK SET, SET OF 4 JAM JAR MAGNETS',
#  'FELTCRAFT GIRL NICOLE KIT, ORGANISER WOOD ANTIQUE WHITE',
#  'BATHROOM SCALES FOOTPRINTS IN SAND, SEWING SUSAN 21 NEEDLE SET',
#  'CRYSTAL DIAMANTE EXPANDABLE RING',
#  '5 STRAND GLASS NECKLACE BLACK',
#  'LOVE HOT WATER BOTTLE, SILVER DISCO HANDBAG',
#  'APPLE BATH SPONGE, EMPIRE UNION JACK TV DINNER TRAY',
#  'DIAMANTE NECKLACE',
#  '3 TRADITIONAl BISCUIT CUTTERS  SET, CREAM DELPHINIUM ARTIFICIAL FLOWER',
#  'NECKLACE+BRACELET SET PINK DAISY, GOLD APERITIF GLASS',
#  'RED SPOT GIFT BAG LARGE, PINK  HONEYCOMB PAPER BALL',
#  'BATHROOM HOOK, EAU DE NILE JEWELLED PHOTOFRAME',
#  'Wrongly mrked had 85123a in box, SET/10 BLUE POLKADOT PARTY CANDLES',
#  'LAVENDER SCENT CAKE CANDLE, 12 MESSAGE CARDS WITH ENVELOPES',
#  'STAR  T-LIGHT HOLDER, SET OF 6 HEART CHOPSTICKS',
#  'FRENCH ENAMEL CANDLEHOLDER, POCKET MIRROR WOODLAND',
#  'TOAST ITS - DINOSAUR',
#  'PARTY TIME PENCIL ERASERS',
#  'ROSE DU SUD WASHBAG, 3 PIECE SPACEBOY COOKIE CUTTER SET',
#  'WATERING CAN SINGLE HOOK PISTACHIO, BLUE EGG  SPOON',
#  'ROSE DU SUD CUSHION COVER, PINK STOCKING CHRISTMAS DECORATION',
#  'T-LIGHT HOLDER SWEETHEART HANGING',
#  'SILVER BOOK MARK WITH BEADS',
#  'ROSE PENDANT TRIPLE SHELL NECKLACE, 75 GREEN FAIRY CAKE CASES',
#  '??, RED METAL BOX TOP SECRET',
#  'VINTAGE DOILY TRAVEL SEWING KIT, LANDMARK FRAME NOTTING HILL',
#  '12 PENCILS TALL TUBE WOODLAND',
#  'SET/20 FRUIT SALAD PAPER NAPKINS, CREAM BUNNY EASTER EGG BASKET',
#  'NUMBER TILE VINTAGE FONT 1, MIRRORED WALL ART LADIES',
#  'ENGLISH ROSE METAL WASTE BIN, VINTAGE CHRISTMAS BUNTING',
#  'ROTATING SILVER ANGELS T-LIGHT HLDR',
#  'STEEL SWEETHEART ROUND TABLE CREAM, SET OF 3 WOODEN HEART DECORATIONS',
#  "DOLLY MIXTURE CHILDREN'S UMBRELLA, HEART SHAPED HOLLY WREATH",
#  'BLUE JUICY FRUIT PHOTO FRAME',
#  'SPACE OWL',
#  'SET OF 36 MUSHROOM PAPER DOILIES, GREEN SWEETHEART BRACELET',
#  'SPACEBOY BABY GIFT SET, FELT FARM ANIMAL RABBIT',
#  'PINK/YELLOW FLOWERS HANDBAG',
#  'DOORMAT VINTAGE LEAVES DESIGN, GLASS JAR MARMALADE',
#  'ENGLISH ROSE SMALL SCENTED FLOWER, VINTAGE RED KITCHEN CABINET',
#  'RED RETROSPOT TISSUE BOX, SNOWSTORM PHOTO FRAME FRIDGE MAGNET',
#  'PAIR OF ENAMEL BUTTERFLY HAIRCLIP',
#  'RIBBON REEL STRIPES DESIGN',
#  'VINTAGE RED KITCHEN CABINET, CHERRY BLOSSOM DECORATIVE FLASK',
#  'LARGE MEDINA STAMPED METAL BOWL, GINGHAM RECIPE BOOK BOX',
#  'NUMBER TILE COTTAGE GARDEN 8',
#  'DRAWER KNOB CERAMIC RED, TIGRIS EYE CHUNKY CHARM BRACELET',
#  'PINK GAUZE BUTTERFLY LAMPSHADE',
#  'BLUE TABLE RUN FLOWER',
#  'KNEELING MAT HOUSEWORK  DESIGN, WRAP DOILEY DESIGN',
#  'SCOTTIES CHILDRENS APRON',
#  'BLACK FEATHER CHRISTMAS DECORATION',
#  'PAPER LANTERN 9 POINT HOLLY STAR L, UNION FLAG WINDSOCK',
#  'RED HEART LUGGAGE TAG',
#  'VINTAGE BEAD PINK EVENING BAG',
#  'VINTAGE KITCHEN PRINT SEAFOOD, CHRISTMAS HANGING STAR WITH BELL',
#  'FIRST CLASS LUGGAGE TAG, PACK OF 12 SKULL TISSUES',
#  'damages/display',
#  'AMETHYST HOOP EARRING FLORAL LEAF',
#  'CAKE STAND VICTORIAN FILIGREE MED, JUMBO BAG PINK POLKADOT',
#  'TRADITIONAL PICK UP STICKS GAME, CERAMIC BIRDHOUSE CRESTED TIT SMALL',
#  'ETCHED GLASS STAR TREE DECORATION',
#  'DIAMOND LAS VEGAS NECKLACE 45CM, ICE CREAM DESIGN GARDEN PARASOL',
#  'RETROSPOT RED WASHING UP GLOVES',
#  'BLUE TRAVEL FIRST AID KIT',
#  'PIECE OF CAMO STATIONERY SET',
#  'BLUE PUDDING SPOON, WRAP FLOWER SHOP',
#  'SCOTTIES CHILDRENS APRON',
#  'CHRISTMAS GINGHAM STAR, DOORMAT I LOVE LONDON',
#  'TRADITIONAL MODELLING CLAY, BOTANICAL ROSE GREETING CARD',
#  '60 CAKE CASES VINTAGE CHRISTMAS',
#  'HEART MIRROR ANTIQUE WHITE, CERAMIC STRAWBERRY CAKE MONEY BANK',
#  'LARGE POPCORN HOLDER, ELEPHANT CARNIVAL POUFFE',
#  'PINK GLASS TASSLE BAG CHARM, GIFT BAG LARGE VINTAGE CHRISTMAS',
#  'PINK BOUDOIR T-LIGHT HOLDER, RED DINER WALL CLOCK',
#  'VINTAGE EMBOSSED HEART',
#  'CALENDAR FAMILY FAVOURITES',
#  'CROCHET ROSE PURSE WITH SUEDE BACK, FRENCH CARRIAGE LANTERN',
#  'SILVER ROCOCO CANDLE STICK',
#  'HEART TRELLISTRIPLE T-LIGHT HOLDER',
#  'ASSORTED TUTTI FRUTTI MIRROR, LIGHT GARLAND BUTTERFILES PINK',
#  'RETROSPOT BABUSHKA DOORSTOP',
#  'PAPERWEIGHT HOME SWEET HOME, PACK OF 12 TRADITIONAL CRAYONS',
#  'PENNY FARTHING BIRTHDAY CARD',
#  'LADLE LOVE HEART RED, ASSORTED SANSKRIT MINI NOTEBOOK',
#  'TRIANGULAR POUFFE VINTAGE, WOOD STOCKING CHRISTMAS SCANDISPOT',
#  'ZINC HEART LATTICE CHARGER SMALL',
#  'GREEN REGENCY TEACUP AND SAUCER',
#  'SKETCHBOOK MAGNETIC SHOPPING LIST',
#  'IVORY HANGING DECORATION  BIRD, FRENCH STYLE STORAGE JAR CAFE',
#  'JUMBO BAG SPACEBOY DESIGN',
#  'CROCHET DOG KEYRING',
#  'CANDY SPOT EGG WARMER RABBIT',
#  'on cargo order',
#  'PACK 3 FIRE ENGINE/CAR PATCHES',
#  'GREETING CARD, STICKY GORDON, PURPLE GEMSTONE NECKLACE 45CM',
#  'FLOWER GLASS GARLAND NECKL.36"BLUE, PANTRY PASTRY BRUSH',
#  'HAND WARMER UNION JACK',
#  'SET OF 10 LANTERNS FAIRY LIGHT STAR',
#  'ANTIQUE TALL SWIRLGLASS TRINKET POT, ROUND ARTICULATED PINK CLOCK W/SUCK',
#  'SET OF 36 TEATIME PAPER DOILIES, FILIGREE DIAMANTE EARRINGS',
#  'PINK BABY BUNTING',
#  'BLOND DOLL DOORSTOP',
#  'SWISS ROLL TOWEL PINK  SPOTS, CARD PSYCHEDELIC APPLES',
#  'CHOCOLATE 3 WICK MORRIS BOX CANDLE, GREEN VINTAGE EARRINGS',
#  'JUMBO BAG SCANDINAVIAN BLUE PAISLEY',
#  'SOLDIERS EGG CUP',
#  'HOME SWEET HOME KEY HOLDER',
#  'TEA PARTY  WRAPPING PAPER',
#  'SET OF 2 TRAYS HOME SWEET HOME, OFFICE MUG WARMER BLACK+SILVER',
#  'SMALL JEWELLERY STAND',
#  'FRENCH KITCHEN SIGN BLUE METAL, JUNGLE POPSICLES ICE LOLLY MOULDS',
#  'ADULT APRON APPLE DELIGHT',
#  'SET/6 COLLAGE PAPER CUPS',
#  'EIGHT PIECE DINOSAUR SET, GIRLS VINTAGE TIN SEASIDE BUCKET',
#  'SCANDINAVIAN 3 HEARTS NAPKIN RING',
#  'BLUE PADDED SOFT MOBILE, 36 PENCILS TUBE RED RETROSPOT',
#  'DECORATIVE WICKER HEART LARGE, PINK FLY SWAT',
#  'MIRRORED DISCO BALL, BLOSSOM IMAGES GIFT WRAP SET',
#  'ETCHED GLASS COASTER, PARTY CONES CANDY ASSORTED',
#  'LUNCH BAG PINK POLKADOT',
#  'SET OF 2 CHRISTMAS DECOUPAGE CANDLE, VICTORIAN  METAL POSTCARD SPRING',
#  'WHITE SILVER NECKLACE SHELL GLASS',
#  'PINK DRAWER KNOB ACRYLIC EDWARDIAN',
#  'SET/4 GARDEN ROSE DINNER CANDLE',
#  'FELT FARM ANIMAL RABBIT, on cargo order',
#  'SET/6 PURPLE BUTTERFLY T-LIGHTS',
#  "DOCTOR'S BAG SOFT TOY, BOX OF 6 ASSORTED COLOUR TEASPOONS",
#  'LETTER HOLDER HOME SWEET HOME, DOORMAT 3 SMILEY CATS',
#  'BISCUIT TIN VINTAGE LEAF, VINTAGE PINK DECORATIVE PARASOL',
#  'BIRTHDAY BANQUET GIFT WRAP, TURQUOISE GLASS TASSLE BAG CHARM',
#  'BUNTING , SPOTTY',
#  'WHITE SAGE INCENSE, CHRISTMAS CRAFT WHITE FAIRY',
#  'TRAVEL CARD WALLET SKULLS',
#  'DAIRY MAID  PUDDING BOWL',
#  'CUT GLASS HEXAGON T-LIGHT HOLDER, LUNCH BAG RED VINTAGE DOILY',
#  'BOX OF 9 PEBBLE CANDLES, ROTATING LEAVES T-LIGHT HOLDER',
#  'CLASSIC WHITE FRAME',
#  "POTTING SHED SOW 'N' GROW SET, JUMBO BAG SCANDINAVIAN BLUE PAISLEY",
#  'CHARLIE+LOLA RED HOT WATER BOTTLE, FOOD/DRINK SPONGE STICKERS',
#  'GOLD DIAMANTE STAR BROOCH',
#  'RED RETROSPOT TISSUE BOX, WRAP POPPIES  DESIGN',
#  'KIDS RAIN MAC PINK, BLUE PATCH PURSE PINK HEART',
#  'ASSORTED SANSKRIT MINI NOTEBOOK, WOODLAND  STICKERS',
#  'WRAP GREEN RUSSIAN FOLKART',
#  'did  a credit  and did not tick ret',
#  '75 BLACK PETIT FOUR CASES, FRYING PAN BLUE POLKADOT',
#  'ZINC HEART FLOWER T-LIGHT HOLDER',
#  'PAPER CRAFT , LITTLE BIRDIE',
#  'CLASSIC FRENCH STYLE BASKET GREEN',
#  'CHARLOTTE BAG DOLLY GIRL DESIGN',
#  'RETRO PLASTIC ELEPHANT TRAY, RUSTIC STRAWBERRY JAM POT LARGE',
#  'Amazon sold sets',
#  'BROWN CHECK CAT DOORSTOP, TUSCAN VILLA DOVECOTE',
#  'SQUARECUSHION COVER PINK UNION FLAG',
#  'BUNDLE OF 3 RETRO EXERCISE BOOKS',
#  'NUMBER TILE COTTAGE GARDEN 4, BLUE WHITE PLASTIC RINGS LAMPSHADE',
#  'CAKE STAND LOVEBIRD 2 TIER WHITE',
#  'EMBROIDERED RIBBON REEL DAISY',
#  'HANGING METAL STAR LANTERN',
#  'WICKER WREATH SMALL, MULTICOLOUR POLKADOT PLATE',
#  'VINTAGE KEEPSAKE BOX PINK FLOWER',
#  'S/12 MINI RABBIT EASTER, water damage',
#  'FUNKY MONKEY CUSHION COVER',
#  'SET OF 12  VINTAGE POSTCARD SET',
#  'IVORY HANGING DECORATION  BIRD',
#  'SMALL GLASS SUNDAE DISH CLEAR, BREAD BIN, DINER STYLE, MINT',
#  'MINI PLAYING CARDS FUN FAIR',
#  'WHITE HANGING BEADS CANDLE HOLDER',
#  'PINK BABY BUNTING',
#  'PARTY FOOD SHOPPER BAG',
#  'M/COLOUR POM-POM CURTAIN, GOLD/AMBER DROP EARRINGS W LEAF',
#  'WHITE CHRISTMAS STAR DECORATION, YULETIDE IMAGES S/6 PAPER BOXES',
#  'KNITTED UNION FLAG HOT WATER BOTTLE, BLUE PAISLEY JOURNAL',
#  'TOAST ITS - DINOSAUR, LOVE HOT WATER BOTTLE',
#  'DAMAGED, RETO LEAVES MAGNETIC SHOPPING LIST',
#  'PINK FLOCK GLASS CANDLEHOLDER, DOG BOWL CHASING BALL DESIGN',
#  'BLACK AND WHITE DOG BOWL',
#  'HYACINTH BULB T-LIGHT CANDLES, wrongly sold sets',
#  'CANDLEHOLDER PINK HANGING HEART, EMBROIDERED RIBBON REEL SOPHIE',
#  'PACK 3 IRON ON DOG PATCHES',
#  'OPEN CLOSED METAL SIGN, SMALL SKULL WINDMILL',
#  'BIRTHDAY CARD, RETRO SPOT, PAINTED METAL PEARS ASSORTED',
#  'ROUND WHITE CONFETTI IN TUBE, ASS FLORAL PRINT SPIRIT LEVEL',
#  'STRING OF 8 BUTTERFLIES,PINK, CURIOUS IMAGES SCRAP BOOK SET',
#  'SWIRLY CIRCULAR RUBBERS IN BAG',
#  'COTTON APRON PANTRY DESIGN, PINK FLOCK SUEDE CUSHION COVER',
#  'CARD GINGHAM ROSE',
#  'PACK OF 12 SKULL TISSUES, NUMBER TILE VINTAGE FONT 0',
#  'PINK UNION JACK  LUGGAGE TAG, LETTER "J" BLING KEY RING',
#  'FRENCH CHATEAU LARGE FRUIT BOWL, 50CM METAL STRING WITH  7 CLIPS',
#  'WHITE MOROCCAN METAL LANTERN',
#  'METAL HERB GERDEN CONTAINER',
#  'YELLOW POT PLANT CANDLE, PICNIC BASKET WICKER 60 PIECES',
#  'HANGING  BUTTERFLY T-LIGHT HOLDER',
#  'SET 36 COLOURING PENCILS DOILY, PARISIENNE CURIO CABINET',
#  'VINTAGE POST OFFICE CABINET, MONTANA DIAMOND CLUSTER NECKLACE',
#  'POLKADOT MUG PINK',
#  'I CAN ONLY PLEASE ONE PERSON MUG, MINITURE ANTIQUE ROSE HOOK IVORY',
#  'RED SPOTTY BISCUIT TIN, CHARLOTTE BAG ALPHABET  DESIGN',
#  'MIDNIGHT BLUE DROP CRYSTAL NECKLACE, SET OF 3 CAKE TINS PANTRY DESIGN',
#  'WOODLAND  HEIGHT CHART STICKERS, TRADITIONAL PICK UP STICKS GAME',
#  'WHITE BAMBOO RIBS LAMPSHADE',
#  'CHRISTMAS STAR WISH LIST CHALKBOARD',
#  'CHERRY BLOSSOM PASSPORT COVER, HEART DECORATION PAINTED ZINC',
#  'ORIGAMI VANILLA INCENSE CONES',
#  '2 PICTURE BOOK EGGS EASTER BUNNY, 60 CAKE CASES VINTAGE CHRISTMAS',
#  'ABSTRACT CIRCLES SKETCHBOOK, KIDS RAIN MAC PINK',
#  'ANTIQUE GLASS PEDESTAL BOWL',
#  '4 PEAR BOTANICAL DINNER CANDLES',
#  'SET/4 DAISY MIRROR MAGNETS, SMALL PARISIENNE HEART PHOTO FRAME',
#  'RAINY LADIES BIRTHDAY CARD, CHILDS BREAKFAST SET SPACEBOY',
#  'PURPLE AMETHYST NECKLACE W TASSEL, MISELTOE HEART WREATH',
#  'SET OF 6 NATIVITY MAGNETS, FORKED CACTUS CANDLE',
#  'ASSORTED COLOUR LIZARD SUCTION HOOK, WHITE SKULL HOT WATER BOTTLE',
#  'AMBER 3 BEAD DROP EARRINGS, GYMKHANNA TREASURE BOOK BOX',
#  'PHOTO FRAME LINEN AND LACE LARGE, NUMBER TILE COTTAGE GARDEN 8',
#  'PINK CHRYSANTHEMUMS ART FLOWER, SET 36 COLOUR PENCILS DOLLY GIRL',
#  'OLD ROSE COMBO BEAD NECKLACE, DOORKNOB CRACKED GLAZE GREEN',
#  'PURPLE FRANGIPANI NECKLACE, GIFT BAG LARGE SPOT',
#  'WOODEN HEART CHRISTMAS SCANDINAVIAN, ASSORTED MINI MADRAS NOTEBOOK',
#  'SUNSET CHECK HAMMOCK',
#  'PINK BITTY LIGHT CHAIN',
#  'BISCUIT TIN VINTAGE LEAF',
#  'PINK CRYSTAL+GLASS BRACELET, SILVER DIAMANTE PEN IN GIFT BOX',
#  'ANIMAL STICKERS',
#  'CREAM WALL PLANTER HEART SHAPED, ZINC WILLIE WINKIE  CANDLE STICK',
#  'VIP HOLIDAY PURSE',
#  'NAMASTE SWAGAT INCENSE',
#  'EGG FRYING PAN MINT, WHITE ROSEBUD & PEARL NECKLACE',
#  'TRANSPARENT ACRYLIC TAPE DISPENSER, MAGNETS PACK OF 4 VINTAGE COLLAGE',
#  'ASSORTED CHEESE FRIDGE MAGNETS',
#  'CROCHET BEAR RED/BLUE  KEYRING, MAXWELL 2 TONE BLUE 60 PAGE PHOTO A',
#  'SET OF 6 T-LIGHTS WEDDING CAKE',
#  'PINK AND BLACK STRING CURTAIN',
#  'FELTCRAFT GIRL AMELIE KIT, SET 10 CARDS HANGING BAUBLES 17080',
#  'FRENCH BLUE METAL DOOR SIGN 9',
#  'CHERUB HEART DECORATION SILVER',
#  'BLACK TEA,COFFEE,SUGAR JARS, HYACINTH BULB T-LIGHT CANDLES',
#  'PINK COMBO MINI CRYSTALS NECKLACE',
#  'AMBER DROP EARRINGS W LONG BEADS, BIRD DECORATION GREEN POLKADOT',
#  'HEART MIRROR ANTIQUE WHITE',
#  'SMALL CHINESE STYLE SCISSOR, WINE BOTTLE DRESSING DARK BLUE',
#  'incorrectly credited C550456 see 47, MAGIC DRAWING SLATE BAKE A CAKE',
#  'BREAD BIN DINER STYLE PINK, PINK CHERRY BLOSSOM CUP & SAUCER',
#  'WOODLAND LARGE RED FELT HEART, WOODEN UNION JACK BUNTING',
#  'HEART SHAPED HOLLY WREATH, ANTIQUE SILVER T-LIGHT GLASS',
#  'DOORMAT 3 SMILEY CATS',
#  'LADIES & GENTLEMEN METAL SIGN, BLUE DISCO HANDBAG',
#  'WHITE HANGING BEADS CANDLE HOLDER',
#  'SET OF 4 NAPKIN CHARMS STARS, HOUSE SHAPE PENCIL SHARPENER',
#  'LAVENDER SCENT CAKE CANDLE',
#  'GLASS BEAD HOOP NECKLACE GREEN',
#  'FAIRY CAKES NOTEBOOK A6 SIZE, ARMY CAMO BOOKCOVER TAPE',
#  "PACK OF 60 DINOSAUR CAKE CASES, YOU'RE CONFUSING ME METAL SIGN",
#  'PINK DRAWER KNOB ACRYLIC EDWARDIAN, GREEN VINTAGE EARRINGS',
#  '4 PINK DINNER CANDLE SILVER FLOCK, BEADED CRYSTAL HEART BLUE SMALL',
#  'PINK HEART SHAPE PHOTO FRAME, WHITE/PINK MINI CRYSTALS NECKLACE',
#  'dotcom sold sets',
#  'MINI  ZINC GARDEN DECORATIONS',
#  'SILVER T-LIGHT SETTING, SET OF 4 CAROUSEL PLACEMATS',
#  'RED RETROSPOT PURSE',
#  'PINK FLORAL FELTCRAFT SHOULDER BAG, EMBROIDERED RIBBON REEL RUBY',
#  'OYSTER TRINKET BOX, TRAVEL CARD WALLET VINTAGE ROSE',
#  'TOP SECRET PEN SET',
#  'SET/4 SPRING FLOWER DECORATION',
#  'SMALL CHINESE STYLE SCISSOR',
#  'JUMBO BAG VINTAGE CHRISTMAS, TROPICAL  HONEYCOMB PAPER GARLAND',
#  'TEA TIME KITCHEN APRON',
#  'SWEETHEART WALL TIDY',
#  'CHARLIE+LOLA RED HOT WATER BOTTLE',
#  'SILVER APERITIF GLASS',
#  'ANT SILVER LIME GREEN BOUDICCA RING, NOEL GARLAND PAINTED ZINC',
#  'DANISH ROSE FOLDING CHAIR',
#  'GREEN ENAMEL+GLASS HAIR COMB',
#  'BLACK FINE BEAD NECKLACE W TASSEL',
#  'KITCHEN METAL SIGN',
#  'TUSCAN VILLA BIRD TABLE, PACK OF 12 DOILEY TISSUES',
#  'POSTAGE, CARD BILLBOARD FONT',
#  'BABY BOOM RIBBONS, LOVE GARLAND PAINTED ZINC',
#  '3 TIER CAKE TIN GREEN AND CREAM',
#  'SILVER/BLACK PENDANT ORBIT NECKLACE, S/4 CACTI CANDLES',
#  'CREAM HANGING HEART T-LIGHT HOLDER, PLASTERS IN TIN VINTAGE PAISLEY',
#  'SPRIG LAVENDER ARTIFICIAL FLOWER',
#  'ASSORTED MINI MADRAS NOTEBOOK, SMALL HAMMERED SILVER CANDLEPOT',
#  'TV DINNER TRAY DOLLY GIRL',
#  'BOTANICAL ROSE GIFT WRAP, ALARM CLOCK BAKELIKE CHOCOLATE',
#  'EIGHT PIECE SNAKE  SET',
#  'michel oops, MIRROR MOSAIC CANDLE PLATE',
#  "RETRO PLASTIC 70'S TRAY, POPPY FIELDS CHOPPING BOARD",
#  'STRIPY DESIGN SHOWER CAP, HAND TOWEL PINK FLOWER AND DAISY',
#  'SET OF 6 SOLDIER SKITTLES, Show Samples',
#  'GLITTER BUTTERFLY CLIPS',
#  'ALARM CLOCK BAKELIKE ORANGE, GREEN FERN JOURNAL',
#  'DOLLY CABINET 2 DRAWERS, STRIPES DESIGN TEDDY',
#  'WHITE VINTAGE CRYSTAL BRACELET',
#  'YELLOW/PINK FLOWER DESIGN BIG MUG, PINK HEARTS LIGHT CHAIN',
#  'CLASSIC GLASS COOKIE JAR, SMALL POLKADOT CHOCOLATE GIFT BAG',
#  'SILVER HANGING T-LIGHT HOLDER',
#  'GARDENIA 1 WICK MORRIS BOXED CANDLE, MEDIUM PARLOUR PICTURE FRAME',
#  'WOVEN ROSE GARDEN CUSHION COVER, REGENCY TEA STRAINER',
#  'CLASSIC WHITE FRAME',
#  'STRAWBERRY HONEYCOMB  GARLAND, GLASS SPHERE CANDLE STAND MEDIUM',
#  'CORONA MEXICAN TRAY, SCANDINAVIAN PAISLEY PICNIC BAG',
#  'PACK OF 6 SKULL PAPER PLATES',
#  '3 TIER CAKE TIN GREEN AND CREAM',
#  'PERIWINKLE T-LIGHT HOLDER',
#  'TRAVEL CARD WALLET I LOVE LONDON',
#  'WHITE BELL HONEYCOMB PAPER',
#  'SET 10 CARD CHRISTMAS WELCOME 17112',
#  'PIN CUSHION BABUSHKA PINK, CHARLIE & LOLA WASTEPAPER BIN FLORA',
#  'BROWN CHECK CAT DOORSTOP, CARAVAN SQUARE TISSUE BOX',
#  'CUBIC MUG FLOCK BLUE ON BROWN',
#  "POTTING SHED SOW 'N' GROW SET",
#  'WRAP WEDDING DAY',
#  'CHRISTMAS TREE HEART DECORATION, DECORATIVE WICKER HEART SMALL',
#  'PHOTO FRAME LINEN AND LACE LARGE, SOAP DISH BROCANTE',
#  'FLOWER GARLAND NECKLACE RED',
#  'JUMBO BAG VINTAGE CHRISTMAS',
#  'A PRETTY THANK YOU CARD',
#  'DIAMANTE NECKLACE PURPLE',
#  'GREEN ROUND COMPACT MIRROR',
#  'BLUE SPOT CERAMIC DRAWER KNOB, ASSORTED COLOURED CIRCLE MOBILE',
#  'HOMEMADE JAM SCENTED CANDLES',
#  'EASTER BUNNY WITH BASKET ON BACK, CRYSTAL STUD EARRINGS ASSORTED COL',
#  'ZINC T-LIGHT HOLDER STAR LARGE, FRUIT SALAD BAG CHARM',
#  'STEEL SWEETHEART ROUND TABLE CREAM, MIRRORED WALL ART LADIES',
#  'BASKET OF TOADSTOOLS, RUSTIC STRAWBERRY JAMPOT LARGE',
#  'SET OF 5 MINI GROCERY MAGNETS, BLUE KNITTED HEN',
#  'BLUE/YELLOW CERAMIC CANDLE HOLDER',
#  'SILVER BLACK ORBIT DROP EARRINGS, CHRISTMAS GINGHAM TREE',
#  'SCOTTIES CHILDRENS APRON',
#  'HANGING CLEAR MINI BOTTLE, CAKE PLATE LOVEBIRD WHITE',
#  'COOK WITH WINE METAL SIGN, DECORATION , WOBBLY RABBIT , METAL',
#  'PINK/AMETHYST/GOLD NECKLACE, GARDENERS KNEELING PAD',
#  'MINI PAINT SET VINTAGE, SUMMER BUTTERFLIES BAG CHARM',
#  'Damages/samples',
#  'ebay, SET/6 FRUIT SALAD PAPER CUPS',
#  'RABBIT NIGHT LIGHT, MAKE YOUR OWN FLOWERPOWER CARD KIT',
#  'WOODEN CROQUET GARDEN SET',
#  'LARGE ROUND WICKER PLATTER, HEART IVORY TRELLIS LARGE',
#  'MAN FLU METAL SIGN',
#  'CRACKED GLAZE EARRINGS RED',
#  'HOUSE SHAPE PENCIL SHARPENER, RUBY DROP CHANDELIER EARRINGS',
#  'EIGHT PIECE SNAKE  SET',
#  'NUMBER TILE COTTAGE GARDEN 8, PINK GREEN EMBROIDERY COSMETIC BAG',
#  'RED RETROSPOT CHILDRENS UMBRELLA, HOT STUFF HOT WATER BOTTLE',
#  'TRELLIS COAT RACK, PLAYING CARDS VINTAGE DOILEY',
#  'CHERRY CROCHET FOOD COVER, SET OF 2 TINS VINTAGE BATHROOM',
#  'SET OF 36 DOLLY GIRL PAPER DOILIES',
#  'HENRIETTA HEN MUG',
#  'SUMMER FUN DESIGN SHOWER CAP',
#  'SET 10 CARDS DINKY TREE 17076, WHITE VINTAGE CRYSTAL EARRINGS',
#  'GINGHAM ROSE WRAP, RETROSPOT BABUSHKA DOORSTOP',
#  'wrongly coded 20713',
#  'PACK OF 6 PANNETONE GIFT BOXES, ST GEORGE SET OF 10 PARTY LIGHTS',
#  'SET 6 FOOTBALL CELEBRATION CANDLES',
#  'RETROSPOT CANDLE  MEDIUM',
#  'CARDHOLDER GINGHAM STAR',
#  'FAMILY PHOTO FRAME CORNICE',
#  ...]

# %%
zeros_labels = np.zeros(len(all_a), dtype=int)

zeros_label_df = pd.DataFrame({"Association Rule antecedants":all_a,
                             "Association Rule consequents":all_c,
                             "label":zeros_labels
                            }, columns = col)

# %%
zeros_label_df.head()
# Out:
#                         Association Rule antecedants  \
# 0                              VINTAGE BILLBOARD MUG
# 1  COLOUR GLASS. STAR T-LIGHT HOLDER, FOLDING UMB...
# 2  LIGHT DECORATION BATTERY OPERATED, BLUE EGG  S...
# 3                    YELLOW BREAKFAST CUP AND SAUCER
# 4                            sold with wrong barcode
#
#                         Association Rule consequents  label
# 0  VINTAGE DONKEY TAIL GAME, SET/2 RED RETROSPOT ...      0
# 1                              PINK POT PLANT CANDLE      0
# 2  PINK RETRO BIG FLOWER BAG, SET OF 72 PINK HEAR...      0
# 3                                               lost      0
# 4                       ZINC HEART LATTICE TRAY OVAL      0

# %%
# concatenate the label 1 and label 0 data
all_df = pd.concat([all_items_df, zeros_label_df], axis=0)

# %%
all_df.shape
# Out:
# (3055, 3)

# %%
not_duplicated_row = all_df.duplicated(['Association Rule antecedants', 'Association Rule consequents'])
not_duplicated_row.value_counts()
# Out:
# False    3055
# dtype: int64

# %%
# shuffle
all_df = all_df[~not_duplicated_row].sample(frac=1).reset_index(drop=True)
all_df.head(10)
# Out:
#                         Association Rule antecedants  \
# 0  WOODLAND CHARLOTTE BAG, CHARLOTTE BAG PINK POL...
# 1                          FRENCH ENAMEL WATER BASIN
# 2     NATURAL SLATE HEART CHALKBOARD, DOTCOM POSTAGE
# 3                                    GIRLS PARTY BAG
# 4      LUNCH BAG SPACEBOY DESIGN, LUNCH BAG WOODLAND
# 5  REGENCY CAKESTAND 3 TIER, NUMBER TILE VINTAGE ...
# 6  3 BLACK CATS W HEARTS BLANK CARD, ILLUSTRATED ...
# 7                  VEGETABLE MAGNETIC  SHOPPING LIST
# 8                              SMALL JEWELLERY STAND
# 9  RED RETROSPOT CHARLOTTE BAG, WOODLAND CHARLOTT...
#
#                         Association Rule consequents  label
# 0  CHARLOTTE BAG SUKI DESIGN, RED RETROSPOT CHARL...      1
# 1  FRENCH BLUE METAL DOOR SIGN 7, CHEST OF DRAWER...      0
# 2                            JUMBO BAG RED RETROSPOT      1
# 3                       BLUE COAT RACK PARIS FASHION      0
# 4                                LUNCH BAG CARS BLUE      1
# 5   Damages/samples, DRAWER KNOB CRACKLE GLAZE GREEN      0
# 6                 NECKLACE+BRACELET SET BLUE BLOSSOM      0
# 7                        SET OF 6 ICE CREAM SKITTLES      0
# 8                      PINK ROSEBUD & PEARL NECKLACE      0
# 9                           STRAWBERRY CHARLOTTE BAG      1

# %%
all_df.to_csv('answer.csv')
